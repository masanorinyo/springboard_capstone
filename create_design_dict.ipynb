# %% [markdown]
# # Creating design dictionary
# # [TODO] - extract out the page logics while deleting other create dictionary files
#
# - same them into csv files.

# %%
import numpy as np
import pandas as pd
import re
import math
import unicodedata

# %%
# file paths
category_file = "raw_data/商品分類表_180410.xlsx"

# for category data
design_df = pd.read_excel(category_file,  sheet_name='Sheet1', index_col=0 )
design_df.columns = ['product_name',
                       'material_type_id',
                       'material_type',
                       'manufacture_country_id',
                       'manufacture_country',
                       'category_id',
                       'category']
design_df.index.name = 'product_id'

# %%
query_keywords = [
    'チェックパッチ',
    'フラワー',
    'フェアアイル',
    'キルト',
    'フリル',
    'ｗｉｒｅ',
    'クロスステッチ', 
    'ヴィンテージ', 
    'クロスステッチ',
    '花柄',
    'チェック',
    'リバーシブル',
    'ボーダー',
    'パッチデニム',
    'イタワチェック',
    'イタワボーダー',
    'レインボー',
    'アンティーク',
    'ダリ',
    'バルメリボーダー',
    'エンブロイダリー',
    'ＪＱパッチデニム',
    'フリル' ,
    'キルト',
    'ジグザグ',
    '藍染め',
    '笠間焼',
    'グラデーション',
    '刺繍',
    'ツウィル',
    'ラップリボン',
    'サークル',
    'アロハ',
    'フリンジ',
    'ライン',
    'ラウンド',
    'レクタングル',
    '２ＷＡＹリボン',
    'スクエア',
    'ウィーブ',
    'パッチワーク',
    'スケルトン',
    'モザイク',
    'トライアングル',
    'ブロウガラス',
    'ツインカラー',
    'カラフル',
    'ネット',
    'バイカラー',
    'クレッセント',
    'クリア',
    'チェッカー',
    'アニマル',
    '薄墨',
    'ストライプ',
    'シーグラス',
    'ドット',
    'ツイスト',
    'ステッチ',
    '耳付き',
    'バーニッシュ',
    'ライト',
    'ボタン',
    'リボン',
    '染ワッフル',
    'オールドパレット',
    '迷彩',
    'ブロックプリント',
    'フラワリング',
    'フェザー',
    'クラッチ',
    'ベーシック',
    'スクイーズ',
    '染め',
    'プリント',
    'ワインディング',
    'ベレーホルダー',
    'エルバ',
    'ストロール',
    'プールス',
    'フルール',
    'パセーオ',
    'ベビッシュ',
    'リーフ',
    'ＷＩＲＥ',
    'トライバル',
    'キューロッホ',
    'イーヴン',
    'フロストアイアン',
    'ラール',
    'リガーレ',
    'クロス',
    'アロング',
    'ヒュプシュ',
    'ポワ',
    'プレーン',
    'スリーブレス',
    'ギボシ',
    'ガルデニア',
    'ナバホ',
    'デリカート',
    'Ｖネック',
    '更紗',
    'シャワー',
    'バード',
    'クローバー',
    'エクレール',
    'ワイヤーハウス',
    'シュティル',
    'ポケット',
    'ルーレ',
    'スパンコール',
    'ＫＨＡＤＩ',
    'ビーンズ',
    'ミックスカラー',
    'サンクリストバル',
    'ライブリーカラード',
    'シェラーフ',
    'ブリュム',
    'フォギーソリッド',
    'レース',
    'スタンピング',
    'ラッテ',
    'フリュール',
    'プードル',
    'アラン',
    'コーン'
]

product_names = [w.replace('\u3000', ' ') for w in design_df['product_name'].tolist()]
print("There are {} product names".format(len(product_names)))
unique_product_names = list(set(product_names))
print("There are {} unique product names".format(len(unique_product_names)))
removing_indexes = []
for index, c in enumerate(unique_product_names.copy()):
    for s in query_keywords:
        if s in c:
            removing_indexes.append(index)

for index in sorted(list(set(removing_indexes)), reverse=True):
    del unique_product_names[index]            

 
print("{} of products still remain unassigned with design".format(len(unique_product_names)))
unique_product_names
# Out:
# There are 21863 product names
# There are 11575 unique product names
# 6211 of products still remain unassigned with design
# ['レギンス スパン ＳＩＬＫ  ',
#  'ＴＥＡＫＷＯＯＤ ディッパーカップ  ',
#  'リューズガラス フードカバー カムリー（Ｓ）  ',
#  'ＭＥＸ．レザーバングル ＭＢ２８８  ',
#  'プントリーニュ ＣＡＰ  ',
#  'アイアンワーク バー フック（Ｌ）  ',
#  'ドールセット ボーイ＆ガール  ',
#  'カンフル ツリー ブロック １０ｐｃｓ  ',
#  'ワーキング リャマ人形 ＡＳＴ  ',
#  'リング セット フィグラ １１号  ',
#  'ハンカチ ４ＳＩＤＥ スカラップクロシェ  ',
#  'ブリキ オーナメント レインディア フロント  ',
#  'リュースガラス プラントポット リム（Ｍ）  ',
#  'ＷＯＯＤ バインドホルダー（Ｓ）  ',
#  'ＢＲＡＳＳ ナンバー パーツ ”０９”  ',
#  'ＲＡＦＦＩＡ クロシェハット  レザーストリング',
#  'ブリムキャップ ウィンドウペーン  ',
#  'テスター ＣＩＮＮＡＭＯＮ  ',
#  'ストール シンプリー ボイル  ',
#  'トートバッグ ＴＷＩＬＬリネン  スペッソ（Ｓ）',
#  'レザー がま口 パース （Ｍ）  ',
#  'カーテン リネン プレーリー  ',
#  'ファーシル ボトルネック プルオーバー  ',
#  'スヌード クロシェ ファンテイル  ',
#  'ファーシル ワンピース  ',
#  'レーテ ブラス ブレス ＢＫシルバー  ',
#  'リネンポーチ ロージット  ',
#  'ワンショルダーバッグ ＴＷＩＬＬ シック  ',
#  'パステール バレッタ  ',
#  'ＣＥＲＡＭＩＣ リム スティック レスト  ＳＴＲＩＰＥ',
#  'ボタニカルメイド ポット Ｗ／プレート（Ｓ）  マヨラナ',
#  'スカートエプロン リネン カロリーナ  ',
#  'ダブルハンドルバッグ トリート リネン  ',
#  'アルミ ワークＣＵＰ（Ｓ）  ',
#  'ロンボス ＢＡＧ  ',
#  'ネックレス アレンジ ウォーターパール  ',
#  ' 特価ＣＴ ￥１００００－  ',
#  'アクタカラー ワンピース  ',
#  'ブレスレット インターバル ヴァリエ  ストーン',
#  'タンクトップ シャンカーコットン リブ  ',
#  'ＲＥＣＹＣＬＥ ＷＯＯＤ コンテナＢＯＸ  ２レイヤー',
#  'シュガー ポコ マフラー  ',
#  'ＩＲＯＮ フォトフレーム （Ｌ）  ',
#  'ブラス セーフティピン（Ｓ）Ｓ／１０  ',
#  'ピアス ランジェ レインドロップ  ',
#  'ＭＥＸ．ＳＶリング Ｌ５１－２９  ',
#  'ＣＡＮ カラードマルシェバッグ Ｍ  ',
#  'ＧＡＬＶＡＮＩＺＥＤ ワークカラー  アレンジバケツ（Ｓ）',
#  '代引き手数料  ３万未満  ',
#  'ホーン タブレットトレイ  レクタングラー（Ｓ）',
#  '商人カード 特典  ',
#  'ＩＲＯＮ バスケット  フィックスハンドル（Ｌ）',
#  'オーバーパンツ ＳＩＬＫ ＆ ＷＯＯＬ  ',
#  'オーガニックコットン ストール  ',
#  'カリマ ワンピース  ',
#  'ＲＥＣＹＣＬＥ ＷＯＯＤ  ＣＨＵＮＫＹボード（Ｌ）',
#  'アイアンワーク アフタヌーンＴＥＡ トレー  （Ｌ）',
#  'レゾン ファー ベレーＣＡＰ  ',
#  'ＢＲＡＳＳ パイプ フレーム ミラー（Ｍ）  ',
#  'リサイクルレザー マット （Ｓ）  ５０×８０ｃｍ',
#  'ボルダード ポンチョ ＫＨ  ',
#  'マルマロン スヌード  ',
#  'ハラコ プチシェル サンダル  ',
#  'ＳＩＬＫ タンクトップ  ',
#  'アニモ アソート ビーズ ブレス  ',
#  'ＷＯＯＬ スニーカー トロット ２４ｃｍ  ',
#  'ＢＡＮＣＵＡＮ ティルト バッグ オーバル  ',
#  'ガルバナイズ ハットスタンドＳ／２  ',
#  'ＢＲＡＳＳ ＣＯＦＦＥＥ スプーン（Ｌ）  ',
#  'ＢＲＡＳＳ スムース ディナーフォーク  ',
#  'ホールドピン レンジ ミンクファー  ',
#  'メイズ バトロン レモン ＢＡＧ  ',
#  'リング トリオ フロート パール １１号  ',
#  'リング デリカ パール ルチア（Ｌ）  ',
#  'ストール タイニー ブルーム  ',
#  'ワンハンドルバッグ キャンバス コンビ  ',
#  'ペルー ＣＡＰ         ＢＥ  ',
#  'ビブエプロン スタンダード リネン  ',
#  'ＨＥＭＰ ヴァーグ サンダル  ',
#  'ビジュー ポーチ  ',
#  'ＲＥＣＹＣＬＥ ＷＯＯＤ トレー  Ｗ／ハンドル（Ｓ）',
#  'トートバッグ グリップ デュレポール  ',
#  'ＧＬＡＳＳ タイニーＦ／Ｖ エッグ（Ｓ）  ',
#  'ＦＬＯＷＥＲ フレグランス ワイドグラス  キャンドル ＣＯＵＮＴＲＹ ＲＯＳＥ',
#  'ＣＥＲＡＭＩＣ リム マグカップ  ',
#  'レザー ＢＯＯＫ ネックレス  ',
#  'ＧＬＡＳＳ ＰＯＬＡＲ ＢＥＡＲ  ',
#  'ラタン ドロワー バスケット（Ｓ）  ',
#  'Ｗ・Ｗ クローゼットラック（Ｓ）  ',
#  'ＲＡＦＦＩＡ バッグ アレス  ',
#  'マフラー クローズ ヘリンボーン  ',
#  'Ｐ・Ｌ グログランキャペリンハット  ',
#  'ローズエッセンス デセナリオ（Ｓ）  ',
#  'ビーズシェル ソリダンテ ブレス  ',
#  'スカル キャミソール ＢＲ  ',
#  'クロシェット パーツ コーム  ',
#  'ＷＯＯＤＥＮ スツール ウォッシュカラー  ',
#  'ペルー ＣＡＰ         ＰＫ  ',
#  'キャップ フロウイング ケーブル キッズ  ',
#  'トロピカルスウェット チュニック ＢＬ  ',
#  'コモダ タクト スリーブ ブラウス  ',
#  'ＷＯＯＤＥＮ オブジェ スタンディング  マッシュルーム（Ｓ）',
#  'コラム ファーハット  ',
#  'アルミ ランプシェード ラウンデッシュ  ',
#  'キャンバス コインパース ポーチ  ',
#  'カンフル アロマミスト  ＣＡＭＰＨＯＲ ＆ ＥＵＣＡＬＹＰＴＵＳ',
#  'ＢＲＡＳＳ ストレイジ フック（Ｍ）  ',
#  'ルームブーツ ループヤーン ブルーマル  ',
#  'ＢＡＮＣＵＡＮ ショルダーバッグ ラテラル  ',
#  'マヒカ ＭＩＸ プルオーバー  ',
#  'ファーシル トーン ＣＡＰ  ',
#  'グレイッシュフィル キャンドルホルダー  バルーン（Ｌ）',
#  'ＷＯＯＬ ソックス チェンジアブル  ',
#  'ＢＲＡＳＳ ローリング ウォール フック  ',
#  '１８Ｓ＆Ｓ Ｒｅｃｒｅａｔｉｏｎａｌ  Ｖｅｈｉｃｌｅ ＮＯ．１',
#  'シャビー アイアン コートハンガー  ',
#  'アイアンワーク ドレス バーハンガー（Ｓ）  ',
#  'ベッドスプレッド グッド デイズ  ',
#  'ＨＯＬＬＹ ＴＲＥＥ Ｗ／ポット（Ｌ）  ',
#  'ＣＥＲＡＭＩＣ デインティ フラット  ピッチャー（Ｌ）',
#  'ＢＡＮＣＵＡＮ ＴＡＬＬ テーパード  バッグ（Ｌ）',
#  'ＬＩＮＥＮキャンバス タウンバッグ  Ｗ／ポーチ',
#  'ＢＲＡＳＳ オーナメント（Ｓ） Ｓ／５  ＳＮＯＷＦＬＡＫＥ',
#  'リューズガラス ステップ タンブラー  トール（Ｌ）',
#  'ポーチ ボーイ  ',
#  'ＭＥＸ．シルバーブローチＤ５１－１３  ',
#  'プレリー ワンピース  ',
#  'グラス トルク キャニスター（Ｌ）  ',
#  'カチューム ブリリアント  ',
#  'アソートハンカチ フロールブーケ  ',
#  'テラコッタ ガーデン プレート（Ｌ）  ',
#  'ＩＲＯＮ フルーツバスケット（Ｌ）  ',
#  'ティーフフィル スタッキング シェルフ  ',
#  '商人カード 特典  部門２  ',
#  'アドラーレ ビーズ ワンピース  ',
#  'ＲＥＳＴＦＯＬＫ ＮＯ．４  ',
#  'プリームム ボア アームウォーマー  ',
#  'キャニスターキャンドル ルーチェ  ＣＯＴＴＯＮ ＬＩＬＹ',
#  'ＡＣＡＣＩＡ ＷＯＯＤ ナチュラル カーブ  カッティングボード（Ｍ） ＷＨ',
#  'ラビットファー ２トーン シュシュ  ',
#  'コーデュロイＥＭＢ ショートパンツ（Ｓ）ＢＥ  ',
#  'ブラシ レクタングラー（Ｌ）  ',
#  'アイアンレッグ シダースツール  ',
#  'ＣＨＩＮＤＩ ＭＡＴ チューズ カラー  ４０×６０ｃｍ',
#  'マフラー トリムリー  ',
#  'ラッフィナート ハンカチ  ',
#  'コッコス ２連ネックレス ＷＨゴールド  ',
#  'ＧＬＡＳＳ フローズンフィル オーナメント  ＴＲＥＥ（Ｓ）',
#  'コッコス ３連ブレス ＢＫシルバー  ',
#  'メイズ ラギッド バッグ  ',
#  'リネン ソブリア ブラウス  ',
#  'ストーンウォッシュ ストール  ',
#  'ＡＢＡＣＡ ソリッドカラー ロングレザー  ハンドル バッグ',
#  'ダブル ＳＩＬＫ ソックス ショート  ',
#  'ＨＯＲＮ ミニ デザートフォーク  ',
#  'アイアンワーク ステップバー ハンガー  ',
#  'ムギワラスリッパ フレシュリネン  ',
#  'ＢＲＡＳＳ フラットＢＯＸ（Ｓ）  ',
#  'ＢＯＢ．Ｍバーニン インセンス  ',
#  'ＬＥＡＴＨＥＲ＆ＡＢＡＣＡ バッグ  フィッシュテール',
#  'ＷＯＯＬ フェドーラ ハット  ',
#  'カラー ブリューム スリッポン ３６  ',
#  'ＯＡＫ ＷＯＯＤ フォトフレーム（Ｓ）  ',
#  'ラフィア ロープワッペン マニッシュＨＡＴ  ',
#  'メイズ デイアウト バッグ  ',
#  'グロセリー ヘアーピン ＲＩＢＢＯＮ  ',
#  'ＢＲＡＳＳ フラットＳフック（Ｍ）  ',
#  'ＨＯＲＮ トーンボトム スープスプーン  ',
#  'ＷＡＳＨＤ ＷＯＯＬ トートバッグ （Ｓ）  ',
#  'ＧＡＬＶＡＮＩＺＥＤ オーバル  ジョーロ（Ｓ）',
#  'リーベル ギャザー ポンチョ ＮＴ×ＮＴ  ',
#  'ＨＯＬＬＹ ＬＥＡＦ リース シャルフ（Ｌ）  ',
#  'ワンショルダーバッグ シェブロン リネン  ',
#  'ＢＡＮＣＵＡＮ バッグ ティーフ（Ｌ）  ',
#  'ＧＡＬＶＡＮＩＺＥＤ インドア ジョーロ  （Ｓ）',
#  'リューズガラス ピッチャー プランプ （Ｌ）  ',
#  'ブローバブル ソリッドカラー グラス  ',
#  'ピアス ショートファー ダブル  ',
#  'ポーチ ティアー ソリッドカラー  ',
#  'アイアンワーク ウォール ２ＷＡＹ ラック  （Ｓ）',
#  'ＷＯＯＤ ウォール ハンギング  ミラーＢＯＸ（Ｌ）',
#  '１７Ｓ＆Ｓ Ｃｏｍｉｄａ Ｃｏｒｒｉｄａ  ',
#  'コインパーツ レザー ヘアーゴム  ',
#  'ＢＲＡＳＳ ソーイング シザー （Ｓ）  Ｗ／ポーチ',
#  'ピアスセット リング＆キューブ  ',
#  'ピアス ＢＲＡＳＳ ＬＩＮＥ（Ｓ）  ',
#  'ＢＲＡＳＳ ベンドキャップＢＯＸ ヘキサゴン  ',
#  'リザード オープントゥ シューズ ３７  ',
#  'ＩＲＯＮ ハンギング バスケット ３レイヤー  ',
#  'ナチュラルウール ＢＥＡＲ（Ｓ）  ',
#  'ＬＩＮＥＮ＆ＣＯＴＴＯＮ ベッドスプレット  ',
#  'ピアス セット アソート ファン  ',
#  'イヤリング エントワイン  ',
#  'ＷＯＯＤ フレーム スタンドミラー ピール  オーバル',
#  'ダブル ＳＩＬＫ ソックス ブリーズ  ',
#  'ブレイドストリング プラントカバー（Ｌ）  ',
#  'ＣＨＩＮＤＩＭＡＴ リサイクル デニム  ９０×１５０ｃｍ',
#  'アンボア キーホルダー ヘッジホグ  ',
#  'ＷＯＯＤ フレーム ディスプレイＣＡＳＥ  トール（Ｓ）',
#  'ドルチェ モチーフ スヌード  ',
#  'ＷＯＯＤ フレーム ディスプレイＣＡＳＥ  ワイド（Ｌ）',
#  'ウィピールノーカラージャケット ＰＵ  ',
#  'トリプリカーレ ブレス  ',
#  'リネン ウォッシュ フレンチスリーブ  ワンピース',
#  'ビビダ ネックレス  ',
#  'ボタニカルメイド バンチ ラベンダー  ショート',
#  'ＷＩＬＬＯＷ バンドル バスケット （Ｌ）  ',
#  'マンテーレ ワンピース  ',
#  'ＭＥＸ．ＳＶピアス Ｂ５１－３  ',
#  'キッズキャップ メイクアップ ＧＩＲＬ  ',
#  'ＢＲＡＳＳ ナンバープレート キーホルダー  ',
#  '■ＯＡＫ ＷＯＯＤ エクル ロング  ミラー（Ｌ）',
#  'アイアンワーク ラスティック  フリングフック（Ｓ）',
#  'ＴＥＡＫＷＯＯＤ ワイドレードル （Ｌ）  ',
#  'ガラスボトル キャンドル ルーチェ  ＣＯＴＴＯＮ ＬＩＬＹ',
#  'ＩＲＯＮ ボウルバスケット フリッシュ（Ｌ）  ',
#  'ラート ボア ＣＡＰ  ',
#  '２８１２２２７ＢＬ ＴＣ コモ  ',
#  'ＲＥＣＹＣＬＥ ＷＯＯＤ オープンシェルフ  バイン（Ｌ）',
#  'アルミ ワークＣＵＰ（Ｍ）  ',
#  'ニトレ ウッドビーズ ２連ネックレス  ',
#  '衿付きポンチョ        ＤＢＲ  ',
#  'ルールン ファブリック ブレス  ',
#  'パハロ シャツ チュニック  ',
#  'トヌス ガルン ボア レッグウォーマー  ',
#  'ブリキ ガーランド フロウスター  ２０Ｐ（Ｓ）',
#  'バッグ オーバルボトム アバットＰ  ',
#  'スカーフピン ティント チェーン  ',
#  'ハンカチ ブルーミング リリィ  ',
#  'ウォッシュレザー リング ブレス  ',
#  'その他 部門５  ',
#  'ＩＲＯＮ プラントホルダー ヒッチ（Ｌ）  ',
#  'ネックレス ＢＲＡＳＳ フリーク  ',
#  'リカーモ ビーズ ストール（ＷＨ×ＰＫ）  ',
#  'オールドフィル スタンド バスケット （Ｌ）  ',
#  'デスクトップ ＭＩＲＲＯＲ  Ｗ／ウッドスタンド（Ｓ）',
#  'リング アドルノ Ｗスヌード （ＯＲ×ＹＬ）  ',
#  'ビジュー スリッポン  ',
#  'プントリーニュ スヌード  ',
#  'ＡＣＡＣＩＡ ＷＯＯＤ ティートレー（Ｌ）  ',
#  'ホーリードロップ シェル ピアス  ',
#  'ブレイドストリング プラントカバー（Ｍ）  ',
#  'ポフィネ イヤーマフ  ',
#  'マーブルポトゥレ スヌード ＤＫ  ',
#  'カリマ ギャザー ブラウス  ',
#  'ＢＡＮＣＵＡＮ ティルト ショルダーバッグ  ',
#  'プランター ブラシ（Ｌ）  ',
#  'ティシュ グラータ スタンドカラーワンピース  ',
#  'ピアス フルブルーム  ',
#  'リサイクル マット デニム マール（Ｓ）  ',
#  'ハラコ ２連ブレス ホルスタイン  ',
#  'ラフィア バッグ網ラフィア 黒  ',
#  'Ｗガーゼ キーホールネック ブラウス  ',
#  'Ｔｅｅｚｅｒｓ．Ｃ．ハニーデュメロン  ',
#  'アンクレット ブクル ビーズ  ',
#  'ＲＡＦＦＩＡ ランジェカラード バッグ  ',
#  'カロー スカート  ',
#  '３ＷＡＹ マウンテンパーカー （Ｓ） ＯＲ  ',
#  'ＢＡＮＣＵＡＮ ショルダーバッグ サック  ',
#  'クリーパーランプ シャイン スクワール  ',
#  'ＳＷＡＲＯＶＳＫＩ カットボール ヘアーピン  ',
#  'シュクレ バロン ブラウス  ',
#  'オブリークネス ストール  ',
#  'ＲＥＣＹＣＬＥ ＷＯＯＤ コンソール（Ｓ）  ',
#  '２８１１２４７ＰＫ ＢＣ チーカ  ',
#  'ポトプリ セーター  ',
#  'ピアス ラピストップ キャッチパール  ',
#  'アービル ハイネック プルオーバー  ',
#  'ホウロウ キャセロール（Ｓ）マーブル  ',
#  'テープ＆ラフィア ブレード ベルト ＨＡＴ  ',
#  'ストール プランタン Ｗ／タッセル  ',
#  'ディスプレイ Ｔスタンド ショート（Ｓ）  ',
#  'シュピール ブークレ ミトン  ',
#  'ＴＩＮアルファベット ナチュラル Ｔ  ',
#  'オールドフィル スタンプ キャンドルホルダー  （Ｌ）',
#  'ワッフル レギンス （Ｌ） ＢＥ  ',
#  'ショルダーバッグ マルカー  ',
#  'ラグロングスカート（Ｓ） ＢＲ  ',
#  '根竹ハンドル １３ｃｍ  ',
#  'ナチュラルクロシェ ７パッチ ドイリー（Ｓ）  ',
#  'ＲＥＳＴＦＯＬＫ ファイル  ',
#  'ＭＥＸ．コロナ テーブル  ',
#  'キャンバス ハット シェーディング  ',
#  'ＩＲＯＮ ドアプレート（Ｓ）  ',
#  'レジェ フラットシューズ ３８  ',
#  'ワンショルダーバッグ ティアー  ソリッドカラー',
#  'ＭＥＸ．ＳＶリング Ｂ５１－３０  ',
#  'ブレスレット ブライス ループ  ',
#  'アンリング ウッドベース カードスタンド  ',
#  'ＢＲＡＳＳ ウォッチ スタンド  ',
#  '１４Ａ＆Ｗ Ｄｅｌｉｇｈｔｆｕｌ キッズ  ',
#  'ＭＩＸメランジフォール ブラウス ＢＬ  ',
#  'ＷＯＯＤ フレーム オーナメント  レインディア',
#  'ブラシ オーバル（Ｌ）  ',
#  'マーケットバッグ ヘッジ パイピング  ',
#  'トートバッグ ブルーメルウール  ',
#  'コンビナーレ ワンピース  ',
#  'ブラス ブレス ＷＨゴールド  ',
#  'ノンブル キャンドル ＷＯＯＤカバー  ＬＡＶＥＮＤＥＲ＆ＦＲＥＥＳＩＡ',
#  'クレール ビーズ ストリング  ',
#  'ホリーツリー キャンドル（Ｌ）  ',
#  'ＢＲＡＳＳ トーションフック（Ｌ）  ',
#  'ＷＯＯＬ ソックス スタンド ヘリンボーン  ',
#  'ゼフィール ワンピース  ',
#  'フルエプロン ポージー  ',
#  'ＢＲＡＳＳ ウォール ハンギング  ポール（Ｓ）',
#  'グランツ Ｌビーズ ブレス＆ネックレス  ',
#  'レーテ ブラス ネックレス ＷＨシルバー  ',
#  'ＫＡＮＴＨＡ ＢＡＧ ミニ  ',
#  'ＭＩＸパーツ ピアス（ミルク）  ',
#  'ＵＳＡ．ＪＡＲ．Ｃチョコレートブラウ  ',
#  'カーテン ペディセル ベルベットテープ  ',
#  'うちわ フェーブル クルール（Ｓ）  ',
#  'ブリキ スタンド ホリデー ツリー（Ｓ）  ',
#  'ＲＡＦＦＩＡ ＫＩＤ’Ｓ ハット ペール  ',
#  'リング ＢＲＡＳＳ デュオ  ',
#  'ストーンウォッシュ ワンピース  ',
#  'トッカーノワンピース ＧＹ  ',
#  'ラフィア ロン チェーン ＨＡＴ  ',
#  'ジューム コットン ＢＡＧ  ',
#  'ＵＳＡ コンチャ（Ｍ） ＡＳ１２８３  ',
#  'ラフィアとリネンの手提げバッグ 苔色  ',
#  'トートバッグ フリスキーＥＭＢ  ',
#  'ティピ裏毛 ワンピース Ｍ→Ｌ ＢＬ  ',
#  'ＢＲＡＳＳ ナンバースタンプ Ｓ／８  Ｗ／ポーチ',
#  'リューズガラス フラットボウル（Ｓ）  ',
#  'ＢＲＡＳＳ ワードローブ ハンガー  ',
#  'ＷＯＯＤ オーナメント カービング ツリー  ',
#  'メキシコ 皮 サイフ  ',
#  'ブレスレット コルド スプリング  ',
#  'ＧＬＡＳＳ フローズンフィル オーナメント  ＳＴＡＲ（Ｓ）',
#  'ピアス プランシュ ペタル  ',
#  'インド ＢＩＮＤＩ  ',
#  'ハンカチ ヴァインローズ  ',
#  'ＢＲＡＳＳ Ｓフック ピエニ Ｓ／６（Ｓ）  ',
#  'ファー ロープ ＢＡＧ  ',
#  'ウォッシュレザー カメラケース  ',
#  'ＩＲＯＮ プランタースタンド  トライポッド（Ｌ） Ｗ／ＧＬＡＳＳベース',
#  'トートバッグ ペイント オーバル（Ｓ）  ',
#  'メーケット ガルン ボア スヌード  ',
#  'チマヨラグメンズフードコート ＰＫＣ  ',
#  'ＣＡＮＶＡＳ デッキシューズ レディース  ２４ｃｍ',
#  'アイアンワーク ラスティック  フリングフック（Ｌ）',
#  'ＡＣＡＣＩＡ ＷＯＯＤ ダストパン ブラック  ',
#  'ＢＲＡＳＳ フラットＳフック（Ｌ）  ',
#  'ＩＲＯＮ スタッキング バスケット  トレー（Ｌ）',
#  'ピアス ＢＲＡＳＳ ＬＩＮＥ（Ｌ）  ',
#  'ブラウンウォッシュ ドレス ミラー  ',
#  'Ｗ・Ｗ ダイング チェアー（Ｓ）  ',
#  'ＴＥＡＫＷＯＯＤ ミニ スパイス スプーン  ',
#  '２８１１２３２ＰＫ ＢＣ エレサー  ',
#  'リネンシャンブレー ナストロ ブラウス  ',
#  'リネンキャンバス ボックス（Ｌ）  ',
#  'アソート クロシェット チェーンＢＡＧ  ',
#  'リューズガラス ボルドー  ',
#  'ＧＡＬＶＡＮＩＺＥＤ オーバルプランター  （Ｍ）',
#  'ポストカード アフリカンＮＡＨＯＫ＠  ',
#  'ＳＶピアス  ',
#  'リューズガラス ベース ボトル（Ｓ）  ',
#  'アイシー Ｌビーズ クリスタル ネックレス  ',
#  'パームＷＡＸキャンドル アルファベット Ａ  ',
#  'カラード マルシェバッグ プルーラ  ',
#  'アイアンワーク ラスティック レングス  “Ｓ”フック（Ｓ）',
#  'ＲＡＦＦＩＡ ハット ブリム クロシェ  ',
#  'ＩＲＯＮ スタッキング トレーＢＯＸ（Ｌ）  ',
#  'Ｗ・Ｗ スクリーン シェルフ ＬＯＷ  ',
#  'ビビダ ウッドホック ブレス  ',
#  'モチーフクロシュ ベスト ＭＴ  ',
#  'ピアス シルフ スノーフレーク パール  ',
#  'ネブラ ガウン コート  ',
#  'ＩＲＯＮ ウォール カードスタンド  ポイントウッド ６ＰＯＣＫＥＴ',
#  'ＲＥＣＹＣＬＥ ＷＯＯＤ サイドテーブル  ',
#  'ＲＥＣＹＣＬＥ ＷＯＯＤ スプリットＢＯＸ  ワイド',
#  'ブラス スパイス スプーン  ',
#  'ムッシェル ピアス（ＳＱＵＡＲＥ）  ',
#  'ＩＲＯＮ ウォールステップラック ５ＳＴＥＰ  ',
#  'ＡＢＡＣＡ フォールドトップ ラージ バッグ  ',
#  'ストール ＬＩＮＥＮ＆ＳＩＬＫ  リンクドロップ',
#  'ＲＥＣＹＣＬＥ ＷＯＯＤ ワイド  シェルフボード（Ｌ）',
#  'ベレーキャップ ウォームリー  ',
#  'フレグランスキャンドル Ｗ／コントワール  キャニスター ＢＡＳＩＬ ＭＡＮＤＡＲＩＮ',
#  'ストロー ボーラー ハット  ',
#  'ＴＩＮアルファベット ナチュラル Ｗ  ',
#  'ＯＲＧＡＮＩＣ ＣＯＴＴＯＮ レギンス  ',
#  'ナチュラルワイヤー ウォールラック（Ｌ）  ',
#  'ビスキュイ ピラーキャンドル Ｓ／６  Ｗ／ポーチ',
#  'アクタカラー チュニック  ',
#  'オールドフィル ビーハイブバスケット トール  （Ｌ）',
#  'リッシュ ボア スリッポン ３８  ',
#  'ＢＲＡＳＳ アクセサリー ステップ バー  （Ｌ）',
#  'ＪＵＴＥ＆ＷＯＯＬ マット ディヴィジョン  （Ｌ） ９０×１３５ｃｍ',
#  'リングセット ディファレント シェイプ  １３号',
#  'ＵＳＡ．ピューターリング コウブ  ',
#  'ＰＨＩ．ココ ネックレスＦＳＨ２０１  ',
#  'リング セット シャルマン ９号  ',
#  'レソルテ バングル  ',
#  'ＲＥＣＹＣＬＥ ＷＯＯＤ ナロウ  シェルフボード（Ｌ）',
#  'ブレスレット パイル チェーン  ',
#  'フードコート リバース ジャガード  ',
#  'ＧＬＡＳＳ フローズンフィル オーナメント  ＴＲＥＥ（Ｌ）',
#  'グローブホルダー ＣＯＣＫ  ',
#  'ＡＣＡＣＩＡ ＷＯＯＤ アレジメント トレー  （Ｓ）',
#  'マット インディアンスタイル  ',
#  'ラフィア帽 あられ  ',
#  'レーテ ブラス ブレス ＢＫゴールド  ',
#  'ティアード マット ４０×６０ｃｍ クルール  ',
#  'ボリビア ローズ ＣＡＰ    ＲＤ  ',
#  'ＡＢＡＣＡ ティルトブリム ハット カシェ  ',
#  'ラメ フラット シューズ ３７  ',
#  'チューヨカーディガン ＧＮ  ',
#  'クロシェット パーツ ホールドピン  ',
#  'ベルベット オーナメント スター  ',
#  'フロル ラー ポーチ （Ｌ）  ',
#  'ピアス スウィング ストーン ドロップ  ',
#  'デゼルト ヘアバンド  ',
#  'ディスプレイ Ｔスタンド ショート（Ｍ）  ',
#  'ピアス ホールド フレーム  ',
#  '２８１１２３９ＰＫ ＢＣ コモ  ',
#  'トートバッグ ショルダー デュレポール  ',
#  '特別値引 部門４  ',
#  'ＯＡＫ ＷＯＯＤ エクル ロング  ミラー（Ｍ）',
#  'ピアス スタント パール  ',
#  'フロアレ ストール（ＷＨ×ＲＤ）  ',
#  'ＵＳＡ コンチャ（Ｍ） ＡＳ１３３５  ',
#  'サンクリとティピワッフルＴシャツ（Ｌ） ＢＬ  ',
#  'ＩＲＯＮ ワイヤーワゴン フェンス  ',
#  'ノンブル グラス キャンドル  ＰＥＲＦＥＣＴ ＡＰＰＬＥ',
#  'リネンバッグ ロージット  ',
#  'ストーンウォッシュ スタンドカラー ガウン  ワンピース',
#  'ルルスス ワンピース  ',
#  'ブラス シザー（Ｍ）オールドスタイル  ',
#  'ＲＥＳＴＦＯＬＫ ＮＯ．２  ',
#  'キッズマフラー クリング ＧＩＲＬ  ',
#  'ヴィグルーズ パイピングポーチ  ',
#  'ＡＢＡＣＡ フロスティング ハット  ',
#  'ブーケ ストール（ＢＬ／Ｓ：ｆｌｏｗｅｒ）  ',
#  'リネン ストール プリム  ',
#  'ＨＭ ブリズフレ ＨＡＴ  ',
#  'ダイヤ ニット ワンピース ＭＴＤ  ',
#  'ＡＲＵＲＯＧ プランタースタンド（Ｓ）  ',
#  'トランク キャンドル ワイド（Ｌ）  ',
#  'メル バタフライ チュニック  ',
#  'コパン コンビネーション アームウォーマー  ',
#  'ネックレス スタッド ストーン  ',
#  'ＩＲＯＮ フレーム ディスプレイケース  カーサ（Ｌ）',
#  'ＡＣＡＣＩＡ ＷＯＯＤ ナチュラル カーブ  カッティングボード（Ｌ） ＷＨ',
#  'キャンドル プレインハウス（Ｌ）  ',
#  'ＭＥＸ．シルバーリング ＭＲ６５１  ',
#  'ヘアーゴム デイン オーバル  ',
#  'ストロー ハット フォーミング  ',
#  'ＬＩＮＥＮキャンバス メッセンジャーバッグ  ',
#  'キッズ マフラー グレイジング  ',
#  'コッコス ３連ネックレス ＷＨシルバー  ',
#  'ガルバナイズ ビルド バケツ（Ｌ）  ',
#  'ＲＥＣＹＣＬＥ ＷＯＯＬ ソリッドカラー  マット ５０×８０ｃｍ',
#  'ニトレ ウッドビーズ ３連ネックレス  ',
#  'ブラス リング＃３  ',
#  'ソポソポ ピアス  ',
#  'アバカ バケット ワンショルダーバッグ  ',
#  'ポーロ ベア ミトン  ',
#  'ランダムアソート パッチ ワンピース  ',
#  'ＴＥＡＫＷＯＯＤ ディナーフォーク ナロー  ',
#  'マルシェバッグ パーヴ  ',
#  'ＰＥＷＴＥＲ ドアプレート（Ｌ）  ',
#  'オールドフィル ブルーム バスケット（Ｓ）  ',
#  'マーケット デイリーバッグ（Ｓ）  ',
#  'ヒートレジスタント マグ（Ｍ）  ',
#  'ルース ＭＩＸビーズ ネックレス  ',
#  'ブリキ セゾンモビール メゾンツリー  ',
#  'シープレザー コインパース スプリングトップ  ',
#  'プラ Ａ．Ｆ バルサム  ',
#  '１８０４６７５ＲＤ コンプロバールスカート  ',
#  'ブラス セーフティピン（Ｌ）Ｓ／５  ',
#  'ジャマイカ ボブ マーリーペンダント  ',
#  'スリッパ スムースファー コートリー  レディース',
#  'ストール ＴＷＩＬＬリネン フォグ カラード  ',
#  'フラットポーチ ルレット  ',
#  'ボア バケツ ＢＡＧ  ',
#  'モルレ ダブル ＣＡＰ  ',
#  'ピアス パテント パール  ',
#  'ＡＣＡＣＩＡ ＷＯＯＤ レクタングラー  トレー（Ｓ）',
#  'アイアン ベル ５．５ｃｍ ＷＲＰ  ',
#  'ミニチュア レディース テーラー  ',
#  'サポテコラグ ミニベスト    ＮＴ  ',
#  'リューズガラス ディスプレイドーム  ストレート（Ｌ）',
#  '２８１１２３５ＫＨ ＢＣ タイダイイウユニ  ',
#  'キャップ ハンドニッティング リブ  ',
#  'ＢＲＡＳＳ ミラー オペラ Ｗ／ポーチ（Ｌ）  ',
#  'ワークグローブ ミッシュ マッシュ  ',
#  'チトニアカットソーＥＭＢ ＯＰ ＧＹＰＫ  ',
#  'ベッドスプレッド ペディセル  ベルベットテープ',
#  'ショルダーバッグ ＯＷＬ  ',
#  'フラップ トート バッグ  ',
#  'フィネッツァ ガーラ ブラウス  ',
#  'モルレ ダブル ヘアーバンド  ',
#  'ディスプレイ Ｔスタンド トール（Ｌ）  ',
#  'リネン ハンガーカバー（Ｓ）  ',
#  'ラミジェーテ ギャザースカート ＢＫ  ',
#  'カンフル オイル  ',
#  'ＴＩＮアルファベット ナチュラル Ｃ  ',
#  '１７Ｓ＆Ｓ Ｒｅｃｒｅａｔｉｏｎａｌ  Ｖｅｈｉｃｌｅ Ｎｏ．１',
#  'フィネッツァ ワンピース  ',
#  '１８０４８１４ＢＫ マイーススカート  ',
#  'ＬＩＮＥＮ ハット ルースン  ',
#  'ノタ チェーン ＢＡＧ  ',
#  'ＷＯＯＬ ソックス ブラッシュ アップ  ',
#  'ストール アクアレール レント  ',
#  'リネア ブランダ レギンス  ',
#  'ブレスレット ガルフ パール  ',
#  'スヌード クロシェ チェイン  ',
#  'ウッド キャニスター（Ｓ）  ',
#  'テラコッタ ガーデンポット ソートカラー  トール（Ｓ）',
#  'ラップド ヘアーゴム Ｓ／１２  ',
#  'クロシェット パーツ（Ｌ）Ｓ／５  ',
#  'ＩＲＯＮ カーブ バスケット ワイド  ',
#  'ウール ストリング Ｓ／３  ',
#  'アイアンワーク キッチンツール ホルダー  ',
#  'スヌード ビーハイブ  ',
#  'イヤリング ルンド パール  ',
#  'ｆｅ シルバーチャームナンバー  ',
#  'タートルネック セーター レビース  ',
#  'エウリュ リブ サスペンダー付 スカート  ',
#  'ふくろう ピロス ミトン  ',
#  'ＷＯＯＤ ツール スタンド（Ｓ）  ',
#  'デイリーウェア プレート （Ｓ）  ',
#  'リング セット ＰＥＡＲＬ ９号  ',
#  'ＲＥＣＹＣＬＥ ＷＯＯＤ トレーＢＯＸ  アイアンハンドル（Ｌ）',
#  'メイズ ロポス ショルダーＢＡＧ  ',
#  'リューズガラス ＷＡＴＥＲ（Ｌ）  ',
#  'ＵＳＡステッカー ベアー ３０９０＠  ',
#  'ＢＲＡＳＳ ドキュメント クリップ（Ｍ）  Ｓ／１０ Ｗ／ポーチ',
#  'スウェードスリッパ ムートンボア レディース  ',
#  'カラー ブリューム スリッポン ３７  ',
#  'ディック ＭＩＸ バレッタ  ',
#  'ヘアーゴム ライズ パール  ',
#  'ＴＥＡＫＷＯＯＤ プラン バター  ',
#  'サイザル スタンドＴＲＥＥ ワイド（Ｌ）  ',
#  'リングセット ディファレント シェイプ  シルバー９２５ １３号',
#  'ヘアーゴム ＢＲＡＳＳ アルコ  ',
#  'ミニョンヌ レザー コースター  ',
#  'パライオン パターンブレス  ',
#  'リカーモ ビーズ ストール（ＷＨ×ＧＮ）  ',
#  'ＰＩＮＥ ＷＯＯＤ オープンＢＯＸ（Ｌ）  ',
#  'ナチュラルウール ＳＨＥＥＰ（Ｓ）  ',
#  'コットン ２ＷＡＹ がま口 ＢＡＧ  ',
#  'オイルレザー カードケース  ',
#  'グローブ ネイル＆ジュエリー チェーン  ',
#  'ロワジール ＨＡＴ  ',
#  'ピアス レッタ パール ロング  ',
#  'キャップ ノッティング  ',
#  'ＲＡＦＦＩＡ トートバッグ ディンティ  ',
#  'パイス カーディガン ＰＫ  ',
#  'モーガル付 ペンダントコード Ｅ２６  ',
#  'ＷＯＯＤＥＮ ウェイト キューブ（Ｌ）  ',
#  'リング デリカ パール エレナ（Ｌ）  ',
#  'ＢＲＡＳＳ フレーム ポルタ（Ｌ）  ',
#  'ＲＥＣＹＣＬＥ ＷＯＯＤ シェルフ  ９ＢＯＸ',
#  'ＴＩＮアルファベットＦリサイクル缶  ',
#  'ＴＥＡＫＷＯＯＤ コンフィチュール  ',
#  'スリッパ スムースファー コートリー  メンズ',
#  'トートバッグ アレー フラグ  ',
#  'ピアス ショートファー プランプ  ',
#  'スプレンダー キャンドル ツリー（Ｓ）  ',
#  'ＢＲＡＳＳ ＴＥＡストレーナー ＲＩＢＢＯＮ  ',
#  'スカル ニットピン  ',
#  'ＲＥＣＹＣＬＥ ＷＯＯＤ ストレージ  パターンＢＯＸ（Ｓ）',
#  'ヘアーバンド プティットクロシェ  ',
#  'フリゾン ウール バレエシューズ３８  ',
#  'レザー ポーチ  ',
#  'ＴＲＩＰ ラフィア ハット（調整ヒモ付）  ',
#  'ＢＲＡＳＳ プレート ピアスホルダー （Ｓ）  ',
#  'ＳＯＲＧＨＵＭ ホウキ（Ｌ）  ',
#  'リング ＢＲＡＳＳ コレット  ',
#  'クッションカバー フロールブーケ ４５ｘ４５  ',
#  'ラスター クロシェ オーバルボトム  トートバッグ',
#  'ＴＩＮアルファベット ナチュラル Ｘ  ',
#  'ソルガム デスクトップ ホウキ スロープ  （Ｓ）',
#  'リング ＢＲＡＳＳ パース ヘキサゴン  ',
#  'ＢＲＡＳＳフレーム アクセサリーケース  レクタングラー',
#  'ＲＥＣＹＣＬＥ ＷＯＯＤ オープンシェルフ  バーハンガー',
#  'ＳＩＬＫ ＆ ＬＩＮＥＮ ソックス  ',
#  'ストール コレクト カレ  ',
#  'ＧＬＡＳＳ バルブベース ディアー（Ｌ）  ',
#  'ＩＲＯＮ アンブレラ スタンド（Ｓ）  ',
#  'グリッター コモド サンダル  ',
#  'デイリーウェア カップ＆ソーサー （Ｌ）  ',
#  'フレ ジュート ＢＡＧ（Ｓ）  ',
#  'センテッド グラス キャンドル  ＡＰＰＬＥ ＢＬＯＳＳＯＭ',
#  'ダブル ＳＩＬＫ ソックス セトルウール  ',
#  'オールドフィル シングル カップ（Ｌ）  ',
#  'ＧＡＲＤＥＮ ＩＲＯＮ シャベル ＯＶＡＬ  ',
#  'ダブルカーテン フロールブーケ  ',
#  'グラニーバッグ スムース  グラニーバッグ スムース',
#  'オールドフィル ビロウ スラントバスケット  （Ｓ）',
#  'アソートファブリック ウェーブ ＢＡＧ  ',
#  'フールペイズリー ショール  ',
#  'ロープ モデスト ＢＡＧ  ',
#  'アルパカ巾着 ショルダーバッグ ＡＳＴ  ',
#  'トートバッグ バーティカルクロシェＳ  ',
#  'ＧＡＲＤＥＮ ＩＲＯＮ シャベル ＫＥＥＮ  ',
#  'ＩＲＯＮ クリップバインダー（Ｌ）  ',
#  'キャンバス スニーカー ステップス ２３ｃｍ  ',
#  'ウッド オブジェ ＡＰＰＬＥ（Ｌ）  ',
#  'ハンドクロシェ ＦＯＯＤカバー  ',
#  'レウァーレ ワンピース  ',
#  'アルファべット ミニチャームＡＤ  ',
#  'トートバッグ パイピング マルカー  ',
#  'ＣＥＲＡＭＩＣ デインティ ボウル（Ｌ）  ',
#  'スクロール クロシェ バッグ  ',
#  'リューズガラス サラダボウル（Ｌ）  ',
#  'ピクニック グローブ  ',
#  'キャンバス デイリートートバッグ（Ｌ）  ',
#  'ＧＬＡＳＳ オーナメント ランタン  ',
#  'ＲＡＦＦＩＡ ボーラーハット ファム  ',
#  'グレフ コットン ＣＡＰ  ',
#  'ＢＲＡＳＳ キャッチフック（Ｍ）  ',
#  'ニエベ ガルン ベスト  ',
#  'ホウロウ ストックＢＯＸ（Ｓ）  ',
#  'タッセル レザー ベルト  ',
#  'ＢＲＡＳＳ グリップ ハンドル（Ｌ）  ',
#  'プエブラワンピース ＫＨ  ',
#  'ＩＲＯＮ チェスト ４ＤＲＡＷＥＲ  ',
#  'コロレ ビーズ リング  ',
#  'ＢＲＡＳＳフレーム ガラスセパレートＢＯＸ  ４ＢＯＸ',
#  'ＲＥＣＹＣＬＥ ＷＯＯＤ ブックシェルフ  （Ｓ）',
#  'オールドフィル ドリップ バケツ （Ｌ）  ',
#  'ＢＲＡＳＳ デザート フォーク リーディ  ',
#  'ラビットファー ホールドピン  ',
#  'ローズエッセンス ロザリオ（Ｌ）  ',
#  'ＴＥＡＫＷＯＯＤ カッティングボード  ',
#  'ブリキ モビール オンブル スノーフレーク  ',
#  'ポトプリ グローブ  ',
#  'アルディ ドルック タンクトップ  ',
#  'シュラーフ パイル プルオーバー  ',
#  'ロータス ハンガー（Ｓ）  ',
#  'メーケット ガルン ボア グローブ  ',
#  'ＭＥＸ．ＳＶリング Ｂ５１－２６  ',
#  'レインディア キャンドル（Ｍ）  ',
#  'ＫＡＮＴＨＡ Ｂ・Ｓ  ',
#  'バッグ小 布編み×ラフィア 赤  ',
#  'ルレイル カラー レッグウォーマー  ',
#  'デュール キャンバス ミニトートＢＡＧ  ',
#  'フェルト ジュエ ブレスレット  ',
#  'アイシー Ｓビーズ クリスタル ネックレス  ',
#  'ウォッシュレザー ヘアーゴム  ',
#  'ＴＲＣ ウール ベッドスプレッド  ',
#  'リネン ストール ハット アジール  ',
#  'ＡＢＡＣＡ ワンショルダーバッグ ピープ  ',
#  'マリンパーツ ヘアーゴム  ',
#  'ＡＢＡＣＡ バッグ ベルクカーブ  ',
#  'フックピアス ＢＲＡＳＳ フリムジー  ',
#  'ＡＢＡＣＡ バッグ マクラメ ブロッサム  ',
#  'オーナメントセット ソーイング  ',
#  'デュクティ キャンバス ミニトートＢＡＧ  ',
#  'ラフィア ローズ ノブレ ＨＡＴ  ',
#  'ノーブル マルシェバッグ オーバル  ',
#  'トートバッグ レザーベルト ワーク  ',
#  'リサイクル メジャー マーケットＢＡＧ  ',
#  'カラーネップ天竺 ティアードパンツ ＢＲ  ',
#  'ズー 手袋 シマウマ  ',
#  'ＳＤ 特価Ｃ／Ｔ（Ｄ）  ',
#  'テラコッタ ガーデンポット トール（Ｍ）  ',
#  'ＴＥＡＫＷＯＯＤ サーブスプーン（Ｌ）  ',
#  'レーヨン インナードレス （Ｌ） ＢＲ  ',
#  'ＲＡＴＴＡＮ バザール バスケット  ',
#  'スヌード アクリット  ',
#  '１９０１０９２ＮＴ ペイズリーエンプキャミソ  ',
#  'ジッパーバッグ ＴＷＩＬＬ シック  ',
#  'グランツ ウォレット  ',
#  'ブレスレット メール ビーズ  ',
#  'ＩＲＯＮ ウォールマガジン スタンド  ６ＰＯＣＫＥＴ',
#  'ウォッシュレザー ロングブレス  ',
#  'ストール ＬＩＮＥＮ ヘリンボーン  ビバーチェ',
#  'ダブルガーゼ ハンカチ ダンデリオン  ',
#  'ＲＡＦＦＩＡ クロシェハット ブリムカラー  ',
#  'ＳＷＡＲＯＶＳＫＩ ティアドロップ  ネックレス',
#  'レザー バネポーチ  ',
#  '和しらべスプーン パンジー  ',
#  'ＲＡＦＦＩＡ ワンハンドル スモールバッグ  ',
#  'リネア ブランダ ワンピース  ',
#  'ボタニカルメイド バンドル プミラ（Ｌ）  ',
#  'ＫＮＯＢ セラミック  ',
#  'ＷＯＯＤ ワークＢＯＸ ストック（Ｌ）  ',
#  'ラルゴ タッセル パース  ',
#  'シャビー アイアン シェルフ トール （Ｓ）  ',
#  'スヌード リプルス  ',
#  'エミスフェール ピアス  ',
#  'トートバッグ ベルベット ファズ（Ｌ）  ',
#  'ＲＡＦＦＩＡ ツウェイン バッグ リフテッド  ',
#  'バブルガラス アイアン ラティス  キャンドルホルダー（Ｓ）',
#  'ＲＥＣＹＣＬＥ ＷＯＯＤ プランクボード  （Ｓ）',
#  'ピアス シルフ スノーフレーク ブラス  ',
#  'ストール ＣＯＴＴＯＮ＆ＳＩＬＫ シエラ  ヘリンボーン',
#  'ＢＡＭＢＯＯ フォールディングテーブル（Ｓ）  ',
#  'ワンショルダーバッグ ＲＥＣＹＣＬＥ  ＷＯＯＬ ラージ ヘリンボーン',
#  'プントリーニュ ビックスリーブ プルオーバー  ',
#  'ＩＲＯＮ ハンギング プラント  バスケット（Ｓ）',
#  'コットンツイル パイピング ジャケット  ',
#  'Ｄ・Ｃ フル ブルーム  ',
#  'ＷＯＯＤクラフト プラントカップ  ',
#  'ＡＲＵＲＯＧ ホワイトウォッシュ  スモール バスケット オーバル',
#  'ポポラス ワンピース  ',
#  'スヌード プリーチング  ',
#  'ＢＡＮＣＵＡＮ トートバッグ ベア（Ｓ）  ',
#  'ＭＥＸ．ＳＶリング Ｂ５１－２５  ',
#  'チトニアカットソーＥＭＢ ＯＰ ＢＫＢＬ  ',
#  'Ｔｅｅｚｅｒｓ．Ｃ．ジンジャーピーチ  ',
#  'ウォッシュレザー テア ブレス  ',
#  'ラビットファー ハンドウォーマー  ',
#  'フォークテイル クー ビーズ ネックレス  ',
#  'ボタニカル キャンドル Ｓ／６ ローズ  ',
#  'ストロー フロリック オーナメントセット  スノーフレーク ４Ｐａｔｔｅｒｎ（Ｌ）',
#  'ラート ボア スヌード  ',
#  'ティピノースリーブワンピース ＢＲ  ',
#  'ＧＡＬＶＡＮＩＺＥＤ カラーリング  ピッチャー（Ｌ）',
#  'ＩＲＯＮ カーブ バスケット トール  ',
#  'ＢＲＡＳＳ レタークリップ（Ｓ）  ',
#  'レザー ワイヤーアクセサリー  ',
#  'ＭＥＸ．サラッペ ６０ｘ１４０ｃｍ  ',
#  'ピアス ブラス フロース  ',
#  'ソリダンテ シェル ブレス  ',
#  'オールドフィル ミニチェアー アーチ  ',
#  'ペルー ＣＡＰ         ＢＬ  ',
#  'パターンウール ポーチ ヘリンボーン  ',
#  'インド ｈｍｔ．腕時計ＳＨＡＫＴＩ  ',
#  'ＣＡＳＴ ＩＲＯＮ ステーショナリー  トレー（Ｌ）',
#  'キュール ワンピース  ',
#  'ＫＩＤ’Ｓ マフラー パフアップ  ',
#  'キッチンパッド テント キャンバス  ',
#  'ＡＢＡＣＡ レール バッグ  ',
#  '蝋引きローズヘアピン  ',
#  'マール ビーズ バレッタ  ',
#  'ピアス ストーンハート  ',
#  'ボタニカルメイド ポット オニオン  ',
#  'ラロ アソート ＢＡＧ  ',
#  'ＩＲＯＮ ドレス スタンド ラック（Ｓ）  ',
#  'サポテコラグ ヘアバンド    ＢＫ  ',
#  'アイビークロシェットレザーネックレス  ',
#  'ＣＥＲＡＭＩＣ デインティ プレート（ＳＳ）  ',
#  'ＴＥＡＫＷＯＯＤ プラン ターナー  ',
#  '１９０６０５８ＧＹ パルシュドレス  ',
#  'ＣＥＲＡＭＩＣ デインティ プレート（Ｌ）  ',
#  'ＣＡＳＴ ＩＲＯＮ トレー プティ （Ｓ）  ',
#  'ＩＲＯＮ イヤーハンドル  ワイヤーバスケット（Ｓ）',
#  'ＷＯＯＤＥＮ ウェイト キューブ（Ｓ）  ',
#  'クラシコ スモック ワンピース  ',
#  'ＧＬＡＳＳ フレーミング ディスプレイ  ハウス（Ｌ）',
#  'ＩＲＯＮ ディスプレイ ハンギングクリップ  ',
#  'ＴＡＫＵＭＩ テープ＆ラフィア ベルトＨＡＴ  ',
#  'インド ロゼンジ ミニマフラー ＯＲ  ',
#  'ＲＡＦＦＩＡ クロースクロシェ ハット  ',
#  'スラープン ドルマンセーター  ',
#  'ＲＡＦＦＩＡ ワンショルダーバッグ フスト  ',
#  'アカアカ ワンピース（ＷＨ×ＯＲ）  ',
#  'ハンドウォーマー ヘアリー  ',
#  'ホワイトウォッシュ マルチフレーム  レクタングラー（Ｌ）',
#  'ドローストーン ハンギングパール ピアス  ',
#  'グローブホルダー ＰＩＧ  ',
#  'パフューム ボトル ブロード  ',
#  'レザーブレスレット ワン フォールド  ',
#  'プレリー ワイド パンツ  ',
#  'グァテマラ 三つ編み ヒモ    ＠  ',
#  'レンク アソート ＢＡＧ  ',
#  '１８０６８２４ＮＶ コロフドレス  ',
#  'キャンディ ストラップ  ',
#  'コーデュロイＥＭＢ サロペットスカート ＧＮ  ',
#  'レザー ディック ブレス  ',
#  'ＨＯＲＮ ミニ デザートスプーン  ',
#  'アソート クロシェット ＢＡＧ  ',
#  'ハンカチ ミックスエレメント  ',
#  'アルファベット クロシェット ＢＡＧ  ',
#  'ブリキ オーナメント ワブル スノーフレーク  ',
#  'ピアス ２ＷＡＹ ポルテ パール  ',
#  'ナチュラル ダブルガーゼ ＦＡＣＥ  ',
#  'ワイヤー ウォールラック １Ｐ  ',
#  'ネックレス ブライス ループ  ',
#  'コッコス ２連ネックレス ＢＫシルバー  ',
#  'ＩＲＯＮ シェルフ ワイヤーボード（Ｓ）  ',
#  'ワッフル パーカー （Ｍ） ＮＶ  ',
#  'ディック レザー （Ｌ）ムーヴメント 腕時計  ',
#  'ＲＡＴＴＡＮ バスケット クラム  ',
#  'ＧＡＬＶＡＮＩＺＥＤ ハンギング トレー  （Ｌ）',
#  'ウィンドウカーテン リネン ブリーズ  ',
#  'ステンレス パティスリー スプーン  ',
#  'ウルー ストリング ネックレス  ',
#  'イヤリング ＢＲＡＳＳ ジル  ',
#  'ＣＨＩＮＤＩＭＡＴ リサイクル デニム  ５０×１５０ｃｍ',
#  'ＩＲＯＮ フォトフレーム ディック（Ｓ）  ',
#  'リーベン ワンピース  ',
#  'ＢＡＮＣＵＡＮ スタウト バッグ オーバル  ',
#  'ズニ パーカー         ＧＮ  ',
#  'ブレスレット ウォーターパール ルクス  ',
#  'ＳＨＥＥＰレザー ポーチ  ',
#  'ワンハンドルバッグ バレル Ｗ／ファーカバー  ',
#  'リング ブリリアント キュービック  ',
#  'ピアス ＢＲＡＳＳ フレームツリー  ',
#  'トロピカルスウェット チュニック ＧＹ  ',
#  'リューズガラス ＣＡＦＦＥ ＬＡＴＴＥ（Ｌ）  ',
#  'ボタニカル リップバーム テスター  ',
#  'シェール チュニック  ',
#  'クレシエンテ スワーブ ＢＡＧ  ',
#  'ホワイトツリー クーヴェル キャンドル（Ｓ）  ',
#  'ブレスレット ダブルチェーン  ',
#  'ブリキ ガーランド ツリー＆ハウス  ',
#  'ヘアーゴム プレート クライス  ',
#  'ブリキ オーナメント オンブル レインディア  ',
#  'パスタン ウォッシュ シャツワンピース  ',
#  'ブルーム グラス キャンドル  ＲＯＳＥ＆ＷＨＩＴＥ ＭＵＳＫ',
#  'ノンブル グラス キャンドル  ＴＥＡ ＬＥＡＶＥＳ',
#  'カリスオン ワンピース  ',
#  'ＭＩＸメランジフォール ブラウス ＲＤ  ',
#  'ＩＲＯＮ シェルフ ワイヤーボード（Ｌ）  ',
#  'マーブル ＳＡＩＢＡＢＡ ２７ｃｍ  ',
#  'ＡＢＡＣＡ バッグ マクラメ パラム  ',
#  'ＲＥＣＹＣＬＥ ＷＯＯＤ ハンディトレー  アイアンハンドル',
#  'ＡＢＡＣＡ ピット ワンハンドル バッグ  ',
#  'レプトス スタンド フォトフレーム（Ｓ）  ',
#  'パルムレ ジャケット  ',
#  'チコビーズ インナーワンピース ＧＮ  ',
#  'ベレーキャップ ファンネル ウェブ  ',
#  'コットンファイル ダブルリング（Ｓ）  ',
#  'てんとうむしストラップ  ',
#  'コンヌード ヘアバンド（細） ＷＨ  ',
#  'カルン パズル アームウォーマー  ',
#  'スピラル スヌード  ',
#  'キャップ フォートレス  ',
#  'シトロネラ テラコッタボウル  キャンドル（Ｌ）',
#  'ＷＯＯＬストール ワームス  ',
#  'バスク ワンピース  ',
#  'フラッフィーウール ＬＩＯＮ（Ｍ）  ',
#  'ＩＲＯＮ ウォール カードスタンド  ポイントウッド ３ＰＯＣＫＥＴ ワイド',
#  'グローブミトン フラッフィネス  ',
#  'ハラコ 腕時計  ',
#  'レッグウォーマー スケイルニット  ',
#  'スターリー キャンドル スノーフレーク（Ｓ）  ',
#  'ラグオパール カーディガン ＢＬ  ',
#  'バレッタ ＢＲＡＳＳ ブリッジ  ',
#  'リューズガラス フードカバー カムリー（Ｌ）  ',
#  'ｃｈｅｅｒ ２０１８ Ａ＆Ｗ ｖｏｌ．１  ',
#  'ヒートレジスタント タンブラー（Ｓ）  ',
#  'シュバム プルオーバー  ',
#  'バッグ ウィンドウペーン  ',
#  'シリンダーバッグ ウィービング  ',
#  'ラタン ドロワー バスケット（Ｍ）  ',
#  'キャンバス フラン がま口 ロング  ',
#  'グローブ ネイル ＆ リストパール  ',
#  'ＩＲＯＮプレート（Ｓ） ＨＯＲＳＥ  ',
#  'ＲＩＳＥ ＲＡＦＦＩＡクロシェハット デリエ  ',
#  'アクタカラー スカート  ',
#  'ＴＥＡＫＷＯＯＤ ティーフォーク  ',
#  'ＰＡＬＭ グランデ ブラック  ',
#  'ネックレス フーゲ ストーン＆パール  ',
#  'ブリーゼ ジップ ガウンカーディガン  ',
#  'ネックレス ポール エンド パール  ',
#  'ＩＲＯＮ ワイヤーシェルフ ティアー  ',
#  'ＲＡＦＦＩＡ ワンハンドル バッグ フリング  ',
#  'トゥーカラキート カフスリーブ ワンピース  ',
#  'イヤリング タプティン パール  ',
#  '１８０６６９３ＧＹ エルソールドレス  ',
#  'ＭＥＸ．ウッド レスラーリング  ',
#  'ナトゥーア シェル ウッド ネックレス  ',
#  'ＡＮＴ ミルト コーディガン  ',
#  'ＳＩＬＫ タイツ ステイド  ',
#  'エペーリス ＦＵＲ ティペット  ',
#  'クッションカバー ヘリンボーン ムジュレ  ',
#  'リネン タック パンツ  ',
#  'ＢＲＡＳＳフレーム ガラスケース  シャンブル（Ｌ）',
#  'リューズガラス ディスプレイドーム  ストレート（Ｓ）',
#  'キャニスターキャンドル ルーチェ  ＬＡＶＥＮＤＥＲ ＢＯＵＱＵＥＴ',
#  'アンブレラ サンシェード リネン  ',
#  'ＬＩＮＥＮ ソックス ミキシング メンズ  メンズ',
#  'リング レール ヴァスト １１号  ',
#  'ピュディーク チュニック  ',
#  'キッズ ミトン グレイジング  ',
#  'ＩＲＯＮ ハンギング ウォールバスケット  ワイド（Ｌ）',
#  'キカ柄 発砲ＰＴ カーディガン ＢＥ  ',
#  'ピアス インターバル ソリッド ストーン  ',
#  'ＩＲＯＮ ウィービング スタンドトレー  ',
#  'ノバ レザー パスケース  ',
#  'パハロ ストール  ',
#  'ハンドウォーマー タイトリーニット  Ｗ／ラビットファー',
#  'ＩＲＯＮ プランタースタンド スモール  トライポッド（Ｓ） Ｗ／ＧＬＡＳＳベース',
#  'ＣＯＥＮ ウァリウス ＭＩＸ ミトン  ',
#  'ＷＯＯＤ ＳＴＩＣＫ スタンド ツリー（Ｌ）  ',
#  'ＭＥＸ．ＳＶピアス Ｂ５１－１２  ',
#  'ＭＥＸ．シルバーリング ００６９７  ',
#  'ガルバナイズ ハンドヘルドボウル（Ｍ）  ',
#  'ズー 手袋 クマ  ',
#  'ルクス キャンドル スター  ',
#  'ＢＲＡＳＳ ハンギング  ポスターホルダー セット（Ｍ）',
#  'テラコッタ ガーデンプレート  ソートカラー（Ｌ）',
#  'ＵＲ グローブネイル＆ジュエリー チェーン  ',
#  'アイアンワーク ラスティック  アンダートレー（Ｌ）',
#  '１８０４６７５ＮＴ コンプロバールスカート  ',
#  'リング グレイン パール １１号  ',
#  'ＴＩＮアルファベット ナチュラル Ｚ  ',
#  'バングル ＢＲＡＳＳ グラース  ',
#  'バスク スリーブ ワンピース  ',
#  'ラルゴ ポーチ  ',
#  'カーテン パフィ プラント  ',
#  'ＲＡＦＦＩＡ ハット シーボート  ',
#  'ピューター シングルフォトフレーム  ファシネイト',
#  'ブリキ スタンドオブジェ フォレストシーン  ',
#  'ＢＲＡＳＳ フラット ウォール フック  ',
#  'ＷＯＯＤワーク カップ（Ｌ）  ',
#  'クリーパーランプ スノー ＣＵＢＥ  ',
#  'キャンバス パテオ がま口 パース（Ｍ）  ',
#  'ＲＡＴＴＡＮ バスケット アーク（Ｌ）  ',
#  'ＩＲＯＮ ＧＬＡＳＳ キャリー ６ＨＯＬＥ  ',
#  'クラシコ パイピング ストール  ',
#  '１５Ａ＆Ｗ Ｃｏｍｉｄａ Ｃｏｒｒｉｄａ  ',
#  'ＩＲＯＮフレーム ガラスケース  レクタングラー（Ｌ）',
#  'ＨＯＬＬＹ ＬＥＡＦ リース シャルフ（Ｍ）  ',
#  'ＬＩＮＥＮ ＆ ＲＡＭＩＥ ソックス メンズ  ',
#  'インド 革取手 ザリＢＡＧ  ',
#  'ＣＡＮ カラード マルシェバッグ パニエ Ｌ  ',
#  'ゲレロフレアーシャツ ＰＵ  ',
#  'フラッフィーウール ＬＩＯＮ（Ｌ）  ',
#  'ブリキ ワイヤーリース フォーリングスター  ',
#  'ＷＯＯＤ プラント カバーＢＯＸ ワイド  Ｗ／アンダートレー',
#  'ベント ヘアーピン（Ｓ）  ',
#  'チトニアカットソー Ｔｓｈ Ｍ→Ｌ ＷＨＰＫ  ',
#  'ダブルカーテン デカラード  ',
#  'ツイード スリッパ オーバーボア レディース  ',
#  'ＩＲＯＮプレート（Ｌ） ＣＯＣＫ  ',
#  'エスプマール ボア レッグウォーマー  ',
#  'バッグ ｉｎ ポーチ フェーブル クルール  ',
#  'ＩＲＯＮ モビール オーナメント ツリー  ',
#  'ＳＨＥＥＰ キャンドル カーム Ｓ／３  ',
#  'ＳＨＥＥＰ キャンドル カーム（Ｓ）  ',
#  'ショール トースティ Ｗ／ホールドピン  ',
#  'ミルト ケーブル プルオーバー  ',
#  '和しらべスプーン バラ  ',
#  'リング デリカ パール ティノ（Ｌ）  ',
#  'ＲＡＦＦＩＡ バッグ ストラート  ',
#  'ピアスセット アソート ミルト  ',
#  'コーデュロイ ミモザ ワンピース  ',
#  'レーヨン インナードレス （Ｍ） ＢＲ  ',
#  'ＩＲＯＮ スタッキング バスケット  ',
#  'ＵＳＡ．ＳＶピアス ＡＰ５０６  ',
#  'フロアレ ストール（ＮＶ×ＲＤ）  ',
#  'ＰＡＮＤＡＮ アソートカラー ＢＡＧ  ',
#  'ＵＳＡ．ＳＶチョーカー ＢＫオニキス  ',
#  'アルミ ボックス Ｗ／セラミック（Ｓ）  ',
#  'ＭＥＸ．ＳＶリング Ｂ５１－３１  ',
#  'ＷＯＯＤ ウィンドウ  ディスプレイＢＯＸ（Ｓ）',
#  'コットンヘンプ ハット  ',
#  'ドライプラント コットンハスク  ',
#  'ＣＥＲＡＭＩＣ リム スティック レスト  ＬＩＮＥ',
#  'ＩＲＯＮ モビール オーナメント スター  スターＳ／３',
#  'チェスナット バケット ボード  ',
#  'パームＷＡＸキャンドル アルファベット Ｎ  ',
#  'ＩＲＯＮ ＷＯＯＤボトム バスケット  ディープ（Ｓ）',
#  'ピューター ディスプレイフレーム オーバル  （Ｌ）',
#  'アルミ ランプシェード クレスト  ',
#  'リーベル ギャザー ポンチョ ＢＫ×ＭＸ  ',
#  'ＷＯＯＤ コースター ソル Ｓ／４  ',
#  'アソート クロシェット ポーチ  ',
#  'ＬＩＮＥＮ＆ＣＯＴＴＯＮ ハット トルス  ',
#  'ティアード マット φ８０ｃｍ クルール  ',
#  'ＬＩＮＥＮ ソックス ラティスワーク  ',
#  'ブーケ ストール（ＢＬ／Ｍ：ｆｌｏｗｅｒ）  ',
#  'ＲＡＴＴＡＮ ハーブ バスケット  ',
#  'レシエンテ スパイラルシェル ネックレス  ',
#  'ＢＲＡＳＳ スウィング フック  ',
#  'ＬＩＮＥＮ ソックス ヒールド カラー  メンズ',
#  'ＢＲＡＳＳ ラッチＫＥＹ（Ｓ）  ',
#  'キャンドル ブロックツリー グローヴ（Ｌ）  ',
#  'ポーチ ＤＯＧ  ',
#  'ＰＥＷＴＥＲ ネームホルダー（Ｍ）  ',
#  'ストール クリンクルピンタック  ',
#  'フェイク ファー ショートベスト  ',
#  'シャビー アイアン シェルフ ワイド  ',
#  'ＷＯＯＤ ウォール ハンギング  ミラーＢＯＸ（Ｓ）',
#  'バッグ リネン＆ブロッサム  ',
#  'ガルバナイズ クランプ レクタングラー  ボックス（Ｓ）',
#  'ポトプリ スヌード  ',
#  'マンテーレ チュニック  ',
#  'ハッピーシャカシャカ ＪＫ Ｍ→Ｌ ＹＬ  ',
#  'ポリュトス ＢＡＧ （ＲＤＭＩＸ）  ',
#  '■ＲＥＣＹＣＬＥ ＷＯＯＤ コンソール  スプレッド（Ｌ）',
#  'ミックスクロシェ カーディガン ＮＶ  ',
#  'ロングネックレス ダブルチェーン  ',
#  'メランジチェーン ２ＲＯＵＮＤ ブレスレット  ',
#  'ＷＯＯＬ ブランケット クラン・タータン  Ｗ／ポーチ',
#  'ＲＡＦＦＩＡ センシティブ ハット  ',
#  'ｆｅ モチーフペンダントトップ  ',
#  'トロピカル ギャザースカート ＹＬ  ',
#  'アマーレ ファー パンツ  ',
#  'ＩＲＯＮ ワイド ベンチ ランバー（Ｓ）  ',
#  'ＨＡＮＫＹＵ クロシェ テイクインバッグ  ',
#  'ストール ＣＯＴＴＯＮ＆ＳＩＬＫ ミゼット  ヘリンボーン',
#  'ブラス ケース オーバル  ',
#  'ピューター フォトフレーム プラン（Ｓ）  ',
#  'ＷＯＯＤ ＳＴＩＣＫ スタンド ツリー（Ｓ）  ',
#  'ＷＯＯＤ フレーム ハンドミラー オーバル  ',
#  'ポトプリ イヤーマフ  ',
#  'ＳＩＬＫ レギンス フォールズ  ',
#  'ＲＡＦＦＩＡ バッグ ブリスク  ',
#  'ＡＢＡＣＡ クロシェ キャリーバッグ  ',
#  ...]

# %%
group_dict = {
    'ボーダー': ['ボーダー'],
    'パレット': ['パレット'],
    'リボン': ['リボン'],
    '花柄': ['フラワー','花']
}


def get_groups(names,group_dict):
    groups = []
    for name in names:
        group_holder = []

        for key in group_dict:
            for query in group_dict[key]:
                if query in name:
                    group_holder.append(key)
                    break

        if group_holder:
            groups.append(",".join(group_holder))
        else:
            groups.append(name)
    return groups

query_keywords = sorted(query_keywords)
names = [ unicodedata.normalize('NFKC', name) for name in [ k.lower().replace(" ","") for k in query_keywords.copy()]]        
groups = get_groups(names,group_dict)

dictionary = { 'query_keywords': query_keywords, 'name': names, 'group': groups }
new_df = pd.DataFrame(dictionary)
new_df
# Out:
#         group      name query_keywords
# 0        アニマル      アニマル           アニマル
# 1         アラン       アラン            アラン
# 2         アロハ       アロハ            アロハ
# 3        アロング      アロング           アロング
# 4      アンティーク    アンティーク         アンティーク
# 5     イタワチェック   イタワチェック        イタワチェック
# 6        ボーダー   イタワボーダー        イタワボーダー
# 7        イーヴン      イーヴン           イーヴン
# 8        ウィーブ      ウィーブ           ウィーブ
# 9       エクレール     エクレール          エクレール
# 10        エルバ       エルバ            エルバ
# 11   エンブロイダリー  エンブロイダリー       エンブロイダリー
# 12       パレット  オールドパレット       オールドパレット
# 13       カラフル      カラフル           カラフル
# 14      ガルデニア     ガルデニア          ガルデニア
# 15     キューロッホ    キューロッホ         キューロッホ
# 16        キルト       キルト            キルト
# 17        キルト       キルト            キルト
# 18        ギボシ       ギボシ            ギボシ
# 19       クラッチ      クラッチ           クラッチ
# 20        クリア       クリア            クリア
# 21     クレッセント    クレッセント         クレッセント
# 22        クロス       クロス            クロス
# 23    クロスステッチ   クロスステッチ        クロスステッチ
# 24    クロスステッチ   クロスステッチ        クロスステッチ
# 25      クローバー     クローバー          クローバー
# 26    グラデーション   グラデーション        グラデーション
# 27        コーン       コーン            コーン
# 28   サンクリストバル  サンクリストバル       サンクリストバル
# 29       サークル      サークル           サークル
# ..        ...       ...            ...
# 97        ラッテ       ラッテ            ラッテ
# 98        リボン    ラップリボン         ラップリボン
# 99        ラール       ラール            ラール
# 100      リガーレ      リガーレ           リガーレ
# 101    リバーシブル    リバーシブル         リバーシブル
# 102       リボン       リボン            リボン
# 103       リーフ       リーフ            リーフ
# 104       ルーレ       ルーレ            ルーレ
# 105     レインボー     レインボー          レインボー
# 106    レクタングル    レクタングル         レクタングル
# 107       レース       レース            レース
# 108   ワイヤーハウス   ワイヤーハウス        ワイヤーハウス
# 109   ワインディング   ワインディング        ワインディング
# 110    ヴィンテージ    ヴィンテージ         ヴィンテージ
# 111        刺繍        刺繍             刺繍
# 112        更紗        更紗             更紗
# 113        染め        染め             染め
# 114     染ワッフル     染ワッフル          染ワッフル
# 115       笠間焼       笠間焼            笠間焼
# 116       耳付き       耳付き            耳付き
# 117        花柄        花柄             花柄
# 118        薄墨        薄墨             薄墨
# 119       藍染め       藍染め            藍染め
# 120        迷彩        迷彩             迷彩
# 121       リボン   2wayリボン        ２ＷＡＹリボン
# 122  jqパッチデニム  jqパッチデニム       ＪＱパッチデニム
# 123     khadi     khadi          ＫＨＡＤＩ
# 124      vネック      vネック           Ｖネック
# 125      wire      wire           ＷＩＲＥ
# 126      wire      wire           ｗｉｒｅ
#
# [127 rows x 3 columns]

# %% [markdown]
# ### Export dictionaries as csv files

# %%
new_df.to_csv('processed_data/design.csv', header=True, mode='w')
