# %% [markdown]
# # Demand forecast analysis
# ---
# - integrate multiple files into one
# - fill or drop the missing observations
# - identify any trends and show it in graph
# ---

# %% [markdown]
# ### Import libraries and define universal variables

# %%
import numpy as np
import pandas as pd
import re
from time import sleep
import math
import matplotlib.pyplot as plt
import codecs

# %% [markdown]
# ### Import data
# *** please don't proceec to the next cell before data tables is shown below the cell.***

# %%
# file paths
size_file = "raw_data/サイズ表記.xlsx"
category_file = "raw_data/商品分類表_180410.xlsx"
color_file = "raw_data/商品カラー略号表180407.xlsx"
sale_file="raw_data/売上データ2014-2017.csv"

with codecs.open(sale_file, "r", "Shift-JIS", "ignore") as file:  # import UTF8 based csv file 
    sales_chunk = pd.read_table( file,
                                 delimiter=",",
                                 parse_dates=['sales_date'],
                                 header=0,
                                 iterator=True,
                                 chunksize=1000,
                                 na_values={'sales_proceed': 0, 'gross_profit': 0, 'area_id': 0},
                                 index_col=['product_id'],
                                 names=['sales_id', 
                                        'product_id',
                                        'product_name',
                                        'retail_price',
                                        'sales_proceeds',
                                        'gross_profit', 
                                        'number_of_sales',
                                        'sales_date',
                                        'raw_cost', 
                                        'most_recent_purchase_date',
                                        'most_recent_order_date',
                                        'number_of_inventory-effective_number',
                                        'manufacture_country_id',
                                        'manufacture_country'] )
    
    sales_df = pd.concat(sales_chunk)  # This makes all chunks saved in memory
    print(sales_df.head(4))
    
# import excel files
# for size data
size_df = pd.read_excel( size_file, sheet_name='Q_最終メモ', header=0, index_col=0 )
size_df.columns = ['size','quality','brand']
size_df.index.name = 'product_id'
print(size_df.head(10))

# for category data
category_df= pd.read_excel(category_file,  sheet_name='Sheet1', index_col=0 )
category_df.columns = ['product_name',
                       'material_type_id',
                       'material_type',
                       'manufacture_country_id',
                       'manufacture_country',
                       'category_id',
                       'category']
category_df.index.name = 'product_id'
print(category_df.head(8))

# for color data
color_df = pd.read_excel(color_file, sheet_name='商品カラー略号表180407', index_col=1).iloc[:,:2]
color_df.columns = ['english_name','japanese_name']
color_df.index.name = 'color_id'
print(color_df.head(8))
# Out:
#             sales_id                                    product_name  \
# product_id
# 103591      20239746  アンティークシダー　フォールディング　　　　  テーブル　（Ｌ）
# 102862      20239747  アンティークシダー　カードホルダー
# 104782      20239747  ティーフフィル　カード　ラック
# 999000      20239747  立替　送料
#
#             retail_price sales_proceeds gross_profit  number_of_sales  \
# product_id
# 103591             18000           9900         6770                1
# 102862              2200           1210          742                1
# 104782              5500           3025         1986                1
# 999000                 0            600          600                1
#
#            sales_date  raw_cost  most_recent_purchase_date  \
# product_id
# 103591     2014-08-01   3130.16                   20140205
# 102862     2014-08-01    507.62                   20140829
# 104782     2014-08-01   1111.26                   20140909
# 999000     2014-08-01      0.00                   20050722
#
#             most_recent_order_date  number_of_inventory-effective_number  \
# product_id
# 103591                           0                                     0
# 102862                           0                                     0
# 104782                           0                                     0
# 999000                           0                                   882
#
#             manufacture_country_id manufacture_country
# product_id
# 103591                        10.0            中国　部門１
# 102862                        10.0            中国　部門１
# 104782                        10.0            中国　部門１
# 999000                         0.0                 NaN
#            size quality brand
# product_id
# 000001      NaN     NaN   NaN
# 011007BE    NaN     NaN   NaN
# 011007GN    NaN     NaN   NaN
# 011007LB    NaN     NaN   NaN
# 011007LG    NaN     NaN   NaN
# 011007NT    NaN     NaN   NaN
# 011007NV    NaN     NaN   NaN
# 011007OR    NaN     NaN   NaN
# 011007PK    NaN     NaN   NaN
# 011007PU    NaN     NaN   NaN
#                product_name  material_type_id material_type  \
# product_id
# AAH080-C    アルファベットチャームＡＤ                 0.0           その他
# AAH080-E    アルファベットチャームＡＤ                 0.0           その他
# AAH080-H    アルファベットチャームＡＤ                 0.0           その他
# AAH080-J    アルファベットチャームＡＤ                 0.0           その他
# AAH080-K    アルファベットチャームＡＤ                 0.0           その他
# AAH080-M    アルファベットチャームＡＤ                 0.0           その他
# AAH080-N    アルファベットチャームＡＤ                 0.0           その他
# AAH080-R    アルファベットチャームＡＤ                 0.0           その他
#
#             manufacture_country_id manufacture_country  category_id category
# product_id
# AAH080-C                      13.0                国内仕入         60.0   アクセサリー
# AAH080-E                      13.0                国内仕入         60.0   アクセサリー
# AAH080-H                      13.0                国内仕入         60.0   アクセサリー
# AAH080-J                      13.0                国内仕入         60.0   アクセサリー
# AAH080-K                      13.0                国内仕入         60.0   アクセサリー
# AAH080-M                      13.0                国内仕入         60.0   アクセサリー
# AAH080-N                      13.0                国内仕入         60.0   アクセサリー
# AAH080-R                      13.0                国内仕入         60.0   アクセサリー
#          english_name japanese_name
# color_id
# AM              ＡＭＢＥＲ          アンバー
# BE              ＢＥＩＧＥ          ベージュ
# BK              ＢＬＡＣＫ          ブラック
# BL               ＢＬＵＥ           ブルー
# BR              ＢＲＯＷＮ          ブラウン
# BZ             BRONZE          ブロンズ
# CF           COLORFUL          カラフル
# CL              ＣＬＥＡＲ          クリアー

# %% [markdown]
# ### Integrate all dataframe into one

# %%
# merging all loaded data into one dataframe
integrated_df = sales_df.loc[:, ['sales_id','product_name','retail_price','sales_proceeds','gross_profit','number_of_sales','sales_date','raw_cost','manufacture_country']]
integrated_df['category'], integrated_df['material_type'] = category_df['category'], category_df['material_type']
integrated_df['size'],integrated_df['quality'],integrated_df['brand'] = size_df['size'],size_df['quality'],size_df['brand']
integrated_df.head(5)
# Out:
#             sales_id                                    product_name  \
# product_id
# 103591      20239746  アンティークシダー　フォールディング　　　　  テーブル　（Ｌ）
# 102862      20239747  アンティークシダー　カードホルダー
# 104782      20239747  ティーフフィル　カード　ラック
# 999000      20239747  立替　送料
# 190038      20239751  ネックレス　インターバル　ヴァリエ　ストーン
#
#             retail_price sales_proceeds gross_profit  number_of_sales  \
# product_id
# 103591             18000           9900         6770                1
# 102862              2200           1210          742                1
# 104782              5500           3025         1986                1
# 999000                 0            600          600                1
# 190038              3800           4560         2592                2
#
#            sales_date  raw_cost manufacture_country  category material_type  \
# product_id
# 103591     2014-08-01   3130.16            中国　部門１　　   インテリア雑貨           木製品
# 102862     2014-08-01    507.62            中国　部門１　　  文具・デスク用品           木製品
# 104782     2014-08-01   1111.26            中国　部門１　　  実用小物・消耗品          金属製品
# 999000     2014-08-01      0.00                 NaN       その他           その他
# 190038     2014-08-01    984.00            韓国　　　　　　    アクセサリー          金属製品
#
#                        size  \
# product_id
# 103591           ８８×６０×７２ｃｍ
# 102862      １８．５×２４．５×８．５ｃｍ
# 104782           ４２×２０×３６ｃｍ
# 999000                  NaN
# 190038                ４５ｃｍ
#
#                                                       quality brand
# product_id
# 103591                                                    NaN   NaN
# 102862                                                （ＣＥＤＡＲ）   NaN
# 104782                                                   ＩＲＯＮ   NaN
# 999000                                                    NaN   NaN
# 190038      ＳＩＬＶＥＲ９２５（１６－Ｋ　ＧＯＬＤ　ＰＬＡＴＥＤ）　ＰＵ：ＡＭＥＴＨＹＳＴ　Ｌ・ＧＹ：Ｌ...   NaN

# %% [markdown]
# ### Extracting data from values
# - extract color information from product_id
# - extract sub-category and size_letter information from product_name
# - extract wholesale price from retail_price, sales_proceed, raw_cost

# %% [markdown]
# #### Extract color name from product_id by comparing with color_df

# %%
# [TODO] - extract out the chunk logics
def get_color_from_product_ids( product_ids, color_df, chunk=50000, lang='japanese_name'):
    ''' 
    Generator function
    Des: extract color information from product_ids while using color dataframe
    and return color list in a specified chunk in order to save memory 
    @product_ids: list
    @color_df: panda dataframe
    @chunk: integer
    @lang: object
    '''
    prev_chunk = 0
    next_chunk = chunk
    last_loop = False
    max_chunk = len(product_ids)
    while True: # loop through product_ids until all values are evaluated
        colors = []
        

        # if the next chunk is over the size of product_id list,
        # then re-define the next chunk with the product_id list size
        if next_chunk > max_chunk:
            last_loop = True
            next_chunk = max_chunk
            
        # the last two characters of product_id matches with color_id
        # if it doesn't match, add to color list as no color 
        for product_id in product_ids[prev_chunk:next_chunk]:
            color_id = product_id[-2:] 
            color = '色なし'
            if color_id in color_df.index:
                color = color_df.loc[color_id,lang]
            colors.append(color)
        yield colors

        if last_loop:
            print("{} color name has been extracted from product_id".format(next_chunk))
            break
        else:
            print("Extracting color name from product_id - currently extracted number: {}".format(next_chunk))
        
        # defining the next chunk
        prev_chunk = next_chunk
        next_chunk = next_chunk + chunk

    
color_lists = get_color_from_product_ids(integrated_df.index.values, color_df)
colors = []
for color_list in color_lists:
    colors = colors + color_list

# Adding extracted color series as a column
integrated_df['color'] = colors
integrated_df.head(5)
# Out:
# Extracting color name from product_id - currently extracted number: 50000
# Extracting color name from product_id - currently extracted number: 100000
# Extracting color name from product_id - currently extracted number: 150000
# Extracting color name from product_id - currently extracted number: 200000
# Extracting color name from product_id - currently extracted number: 250000
# Extracting color name from product_id - currently extracted number: 300000
# Extracting color name from product_id - currently extracted number: 350000
# Extracting color name from product_id - currently extracted number: 400000
# Extracting color name from product_id - currently extracted number: 450000
# Extracting color name from product_id - currently extracted number: 500000
# Extracting color name from product_id - currently extracted number: 550000
# Extracting color name from product_id - currently extracted number: 600000
# Extracting color name from product_id - currently extracted number: 650000
# Extracting color name from product_id - currently extracted number: 700000
# Extracting color name from product_id - currently extracted number: 750000
# Extracting color name from product_id - currently extracted number: 800000
# Extracting color name from product_id - currently extracted number: 850000
# 876339 color name has been extracted from product_id
#             sales_id                                    product_name  \
# product_id
# 103591      20239746  アンティークシダー　フォールディング　　　　  テーブル　（Ｌ）
# 102862      20239747  アンティークシダー　カードホルダー
# 104782      20239747  ティーフフィル　カード　ラック
# 999000      20239747  立替　送料
# 190038      20239751  ネックレス　インターバル　ヴァリエ　ストーン
#
#             retail_price sales_proceeds gross_profit  number_of_sales  \
# product_id
# 103591             18000           9900         6770                1
# 102862              2200           1210          742                1
# 104782              5500           3025         1986                1
# 999000                 0            600          600                1
# 190038              3800           4560         2592                2
#
#            sales_date  raw_cost manufacture_country  category material_type  \
# product_id
# 103591     2014-08-01   3130.16            中国　部門１　　   インテリア雑貨           木製品
# 102862     2014-08-01    507.62            中国　部門１　　  文具・デスク用品           木製品
# 104782     2014-08-01   1111.26            中国　部門１　　  実用小物・消耗品          金属製品
# 999000     2014-08-01      0.00                 NaN       その他           その他
# 190038     2014-08-01    984.00            韓国　　　　　　    アクセサリー          金属製品
#
#                        size  \
# product_id
# 103591           ８８×６０×７２ｃｍ
# 102862      １８．５×２４．５×８．５ｃｍ
# 104782           ４２×２０×３６ｃｍ
# 999000                  NaN
# 190038                ４５ｃｍ
#
#                                                       quality brand color
# product_id
# 103591                                                    NaN   NaN   色なし
# 102862                                                （ＣＥＤＡＲ）   NaN   色なし
# 104782                                                   ＩＲＯＮ   NaN   色なし
# 999000                                                    NaN   NaN   色なし
# 190038      ＳＩＬＶＥＲ９２５（１６－Ｋ　ＧＯＬＤ　ＰＬＡＴＥＤ）　ＰＵ：ＡＭＥＴＨＹＳＴ　Ｌ・ＧＹ：Ｌ...   NaN   色なし

# %% [markdown]
# #### Extract subcategory from product_name by comparing with subcategory_df

# %% [markdown]
# #### Extract material from product_name and quality by comparing with material_df
# - [TODO] don't forget to get the numerical vallue after the listed material: ex) cotton 100%

# %% [markdown]
# #### Extract brand information from brand

# %% [markdown]
# #### Extract sub-category and size_letter info from product_name

# %%
# [TODO] - extract out the chunk logics
def get_subcategories_and_size_letter_from_name( names, chunk=50000):
    ''' 
    Generator function
    '''
    prev_chunk = 0
    next_chunk = chunk
    last_loop = False
    max_chunk = len(names)
    while True: # loop through product_ids until all values are evaluated
        subcategories = []
        size_letters = []
        

        # if the next chunk is over the size of product_id list,
        # then re-define the next chunk with the product_id list size
        if next_chunk > max_chunk:
            last_loop = True
            next_chunk = max_chunk
            
        # [TODO] logics goes here
        # - extract size letter
        # - extract sub-category and clean it
        for name in names[prev_chunk:next_chunk]:

            # extracing out size letter information
            found = re.search("\（.*?\）",name)
            if found:
                size_letter = name[found.start()+1].lower()
                name = name[:found.start()] + name[found.end():]
            else:
                size_letter = 'no size letter'
                
            # extracing subcategory information
#             subcategory = ','.join(map(lambda x:x.lower(), sorted(name.split())))
            subcategory = name.lower()
            # clean subcategory
            # - step one - unique values
            # - compare one by one
                        
            subcategories.append(subcategory)
            size_letters.append(size_letter)
        yield {'subcategory':subcategories, 'size_letter': size_letters }

        if last_loop:
            print("{} subcategory and size letter has been extracted from product_name".format(next_chunk))
            break
        else:
            print("Extracting subcategory and size letter from product_name - currently extracted number: {}".format(next_chunk))
        
        # defining the next chunk
        prev_chunk = next_chunk
        next_chunk = next_chunk + chunk

        
# getting generator list which contains extracted subcategory and size letter values
product_names = [w.replace('\u3000', ' ') for w in integrated_df['product_name'].tolist()]
extracted_lists = get_subcategories_and_size_letter_from_name(product_names)

# looping through generator list in batches to get subcategory and size_letter series 
subcategories = []
size_letters = []
for extracted in extracted_lists:
    subcategories = subcategories + extracted['subcategory']
    size_letters = size_letters + extracted['size_letter']
    
# adding extracted data to integrated dataframe as new columns
# integrated_df['sub_category'] = subcategories
integrated_df['size_letter'] = size_letters
# integrated_df.head(5)

integrated_df
# Out:
# Extracting subcategory and size letter from product_name - currently extracted number: 50000
# Extracting subcategory and size letter from product_name - currently extracted number: 100000
# Extracting subcategory and size letter from product_name - currently extracted number: 150000
# Extracting subcategory and size letter from product_name - currently extracted number: 200000
# Extracting subcategory and size letter from product_name - currently extracted number: 250000
# Extracting subcategory and size letter from product_name - currently extracted number: 300000
# Extracting subcategory and size letter from product_name - currently extracted number: 350000
# Extracting subcategory and size letter from product_name - currently extracted number: 400000
# Extracting subcategory and size letter from product_name - currently extracted number: 450000
# Extracting subcategory and size letter from product_name - currently extracted number: 500000
# Extracting subcategory and size letter from product_name - currently extracted number: 550000
# Extracting subcategory and size letter from product_name - currently extracted number: 600000
# Extracting subcategory and size letter from product_name - currently extracted number: 650000
# Extracting subcategory and size letter from product_name - currently extracted number: 700000
# Extracting subcategory and size letter from product_name - currently extracted number: 750000
# Extracting subcategory and size letter from product_name - currently extracted number: 800000
# Extracting subcategory and size letter from product_name - currently extracted number: 850000
# 876339 subcategory and size letter has been extracted from product_name
#             sales_id                                    product_name  \
# product_id
# 103591      20239746  アンティークシダー　フォールディング　　　　  テーブル　（Ｌ）
# 102862      20239747  アンティークシダー　カードホルダー
# 104782      20239747  ティーフフィル　カード　ラック
# 999000      20239747  立替　送料
# 190038      20239751  ネックレス　インターバル　ヴァリエ　ストーン
# 190039      20239751  ブレスレット　インターバル　ヴァリエ　　　　  ストーン
# 190044      20239751  ブレスレット　アレンジ　ウォーターパール
# 190046      20239751  ネックレス　ＢＲＡＳＳ　ティップ
# 190047      20239751  ピアス　ＢＲＡＳＳ　ティップ
# 190064      20239751  リング　セット　ＬＩＮＥ　１１号
# 190065      20239751  リング　セット　ＬＩＮＥ　９号
# 190066      20239751  リング　セット　ＰＥＡＲＬ　１１号
# 190067      20239751  リング　セット　ＰＥＡＲＬ　９号
# 190094OR    20239751  ピアスセット　ジェルフラワー＆スワロフスキー
# 190094WH    20239751  ピアスセット　ジェルフラワー＆スワロフスキー
# 190117      20239751  ヘアーゴム　ライズ　パール
# 190119      20239751  ヘアーゴム　フォールドスクエア　パール
# 308353BL    20239751  リネン　ソリッドカラー　ツイル　ストール
# 308353GN    20239751  リネン　ソリッドカラー　ツイル　ストール
# 308353MT    20239751  リネン　ソリッドカラー　ツイル　ストール
# 308353NV    20239751  リネン　ソリッドカラー　ツイル　ストール
# 308353PK    20239751  リネン　ソリッドカラー　ツイル　ストール
# 371337      20239751  リューズガラス　ＴＥＡ（Ｌ）
# 371338      20239751  リューズガラス　ＴＥＡ（Ｓ）
# 371424      20239751  リューズガラス　マグカップ　ストレート（Ｌ）
# 371426      20239751  リューズガラス　マグカップ　ラウンド　（Ｌ）
# 190056      20239752  ネックレス　ラウンド　キュービック
# 103434OR    20239753  アンダリチェック　ポーチ　（Ｌ）
# 307899BL    20239753  マーケットバッグ　クロース　フラワー　　　　  Ｗ／ラミネート
# 307899OR    20239753  マーケットバッグ　クロース　フラワー　　　　  Ｗ／ラミネート
# ...              ...                                             ...
# 307001      60366107  ブラス　アクセサリー　スタンド　（Ｌ）
# 307002      60366107  ブラス　アクセサリー　スタンド　（Ｓ）
# 308973      60366107  ＢＲＡＳＳ　カードスタンド　ワイド　Ｓ／１０
# 371738      60366107  リューズガラス　バルブ　ボトル（Ｌ）
# 371814      60366107  リューズガラス　フラワーベース　ネック（Ｓ）
# 371902      60366107  リューズガラス　クーレライン　ピッチャー　　  テーパー（Ｌ）
# 106681BK    60366108  アンダリ　ハット　ティアー
# 106624NV    60366111  テーパード　バッグ　コロール
# 106673NV    60366111  アンダリ　バッグ　リップル　ウェーブ
# 106681BK    60366111  アンダリ　ハット　ティアー
# 422843YL    60366114  ＡＢＡＣＡ　バッグ　パウロ
# 308996B     60366116  トートバッグ　キャンバス　タイル　　　　　　  フィールストライプ
# 422707      60366116  ＲＥＣＹＣＬＥ　ＷＯＯＤ　　　　　　　　　　  ハンギングＢＯＸ（Ｓ）
# 190225      60366117  ピアス　リファインド　フラワー
# 301974      60366118  グラス　カップ　バーレル（Ｌ）
# 301975      60366118  グラス　カップ　バーレル（Ｓ）
# 308229GY    60366118  ディッシュクロス　シェヴロン　ＬＩＮＥＮ
# 308229WH    60366118  ディッシュクロス　シェヴロン　ＬＩＮＥＮ
# 307858BE    60366119  リネン　ランチバッグ　ソリッドカラー　　　　  Ｗ／ポイント　フラワー
# 308407      60366119  ＢＲＡＳＳ　カトラリーレスト
# 308451BR    60366119  ハンカチ　ＴＷＩＬＬ　ストライプ　　　　　　  ディープカラー
# 308451NV    60366119  ハンカチ　ＴＷＩＬＬ　ストライプ　　　　　　  ディープカラー
# 371595      60366119  リューズガラス　コンテント　キャニスター　　  プランプ（Ｌ）
# 999000      60366119  立替　送料
# 307858BE    60366120  リネン　ランチバッグ　ソリッドカラー　　　　  Ｗ／ポイント　フラワー
# 303057GY    60366121  ランチマット　リネン　カロリーナ
# 303115      60366121  ヒートレジスタント　マグ（Ｍ）
# 106684BK    60366124  パイピング　ハンドル　バッグ　クルサール
# 105976WH    60366127  ＲＡＦＦＩＡ　スタンピング　ＫＩＤ’Ｓハット
# 371338      60366130  リューズガラス　ＴＥＡ（Ｓ）
#
#             retail_price sales_proceeds gross_profit  number_of_sales  \
# product_id
# 103591             18000           9900         6770                1
# 102862              2200           1210          742                1
# 104782              5500           3025         1986                1
# 999000                 0            600          600                1
# 190038              3800           4560         2592                2
# 190039              3000           3600         2062                2
# 190044              3000           3600         2224                2
# 190046              4200           5040         3090                2
# 190047              2800           3360         2212                2
# 190064              5500           3300         1881                1
# 190065              5500           3300         1881                1
# 190066              4800           5760         3168                2
# 190067              4800           5760         3168                2
# 190094OR            2800           3360         2066                2
# 190094WH            2800           3360         2066                2
# 190117              1800           2160         1334                2
# 190119              1800           2160         1196                2
# 308353BL            4800           2880         1708                1
# 308353GN            4800           2880         1708                1
# 308353MT            4800           2880         1708                1
# 308353NV            4800           2880         1708                1
# 308353PK            4800           2880         1708                1
# 371337               600           2160         1512                6
# 371338               500           1800         1177                6
# 371424              1200           2160         1428                3
# 371426              1500           2700         1824                3
# 190056              3800           2280         1355                1
# 103434OR             700           1260          438                6
# 307899BL            3800           1140           40                1
# 307899OR            3800           1140           40                1
# ...                  ...            ...          ...              ...
# 307001              1200           4320         2190                6
# 307002              1000           3600         1812                6
# 308973              2800           5040         2934                3
# 371738              2000           1201          809                1
# 371814              2800           5040         3198                3
# 371902              2800           3360         2242                2
# 106681BK            3800          -1710        -1710               -1
# 106624NV            3300          -1485        -1485               -1
# 106673NV            5800          -2610        -2610               -1
# 106681BK            3800          -3420        -3420               -2
# 422843YL            7800          -3510        -3510               -1
# 308996B             4800          -1920        -1920               -1
# 422707              3500          -1400        -1400               -1
# 190225              3500          -1750        -1750               -1
# 301974               280           2268          828               18
# 301975               180           1458          310               18
# 308229GY            1800            810          377                1
# 308229WH            1800            810          377                1
# 307858BE            2800           1260          592                1
# 308407               700           1890          755                6
# 308451BR             800           1800          815                5
# 308451NV             800           1800          815                5
# 371595              4800           2160          917                1
# 999000                 0            600          600                1
# 307858BE            2800          -1680        -1680               -2
# 303057GY            1500           -780         -780               -1
# 303115              1200          -1248        -1248               -2
# 106684BK            6500           1300         1300                1
# 105976WH            4200           1470          292                1
# 371338               500           -300         -300               -1
#
#            sales_date  raw_cost manufacture_country  category material  \
# product_id
# 103591     2014-08-01   3130.16            中国　部門１　　   インテリア雑貨      木製品
# 102862     2014-08-01    507.62            中国　部門１　　  文具・デスク用品      木製品
# 104782     2014-08-01   1111.26            中国　部門１　　  実用小物・消耗品     金属製品
# 999000     2014-08-01      0.00                 NaN       その他      その他
# 190038     2014-08-01    984.00            韓国　　　　　　    アクセサリー     金属製品
# 190039     2014-08-01    769.00            韓国　　　　　　    アクセサリー     金属製品
# 190044     2014-08-01    688.00            韓国　　　　　　    アクセサリー     金属製品
# 190046     2014-08-01    975.00            韓国　　　　　　    アクセサリー     金属製品
# 190047     2014-08-01    574.00            韓国　　　　　　    アクセサリー     金属製品
# 190064     2014-08-01   1419.00            韓国　　　　　　    アクセサリー     金属製品
# 190065     2014-08-01   1419.00            韓国　　　　　　    アクセサリー     金属製品
# 190066     2014-08-01   1296.00            韓国　　　　　　    アクセサリー     金属製品
# 190067     2014-08-01   1296.00            韓国　　　　　　    アクセサリー     金属製品
# 190094OR   2014-08-01    647.00            韓国　　　　　　    アクセサリー     金属製品
# 190094WH   2014-08-01    647.00            韓国　　　　　　    アクセサリー     金属製品
# 190117     2014-08-01    413.00            韓国　　　　　　    アクセサリー     金属製品
# 190119     2014-08-01    482.00            韓国　　　　　　    アクセサリー     金属製品
# 308353BL   2014-08-01   1172.00            インド　１　　　    スカーフＡＷ      布製品
# 308353GN   2014-08-01   1172.00            インド　１　　　    スカーフＡＷ      布製品
# 308353MT   2014-08-01   1172.00            インド　１　　　    スカーフＡＷ      布製品
# 308353NV   2014-08-01   1172.00            インド　１　　　    スカーフＡＷ      布製品
# 308353PK   2014-08-01   1172.00            インド　１　　　    スカーフＡＷ      布製品
# 371337     2014-08-01    126.86            ベトナム　　　　      台所用品    ガラス製品
# 371338     2014-08-01    123.04            ベトナム　　　　      台所用品    ガラス製品
# 371424     2014-08-01    244.00            ベトナム　　　　      台所用品    ガラス製品
# 371426     2014-08-01    292.00            ベトナム　　　　      台所用品    ガラス製品
# 190056     2014-08-01    925.00            韓国　　　　　　    アクセサリー     金属製品
# 103434OR   2014-08-01    137.00            中国　部門１　　   バッグ・サイフ     天然繊維
# 307899BL   2014-08-01   1100.00            インド　１　　　   バッグ・サイフ      布製品
# 307899OR   2014-08-01   1100.00            インド　１　　　   バッグ・サイフ      布製品
# ...               ...       ...                 ...       ...      ...
# 307001     2017-07-28    331.62            インド　１　　　  実用小物・消耗品     金属製品
# 307002     2017-07-28    277.51            インド　１　　　  実用小物・消耗品     金属製品
# 308973     2017-07-28    633.09            インド　１　　　  実用小物・消耗品     金属製品
# 371738     2017-07-28    385.62            ベトナム　　　　      園芸用品    ガラス製品
# 371814     2017-07-28    605.00            ベトナム　　　　      園芸用品    ガラス製品
# 371902     2017-07-28    559.00            ベトナム　　　　      台所用品    ガラス製品
# 106681BK   2017-07-28    824.00            中国　部門１　　  手袋帽子マフラＳ     天然繊維
# 106624NV   2017-07-28    657.09            中国　部門１　　   バッグ・サイフ      その他
# 106673NV   2017-07-28   1368.00            中国　部門１　　   バッグ・サイフ     天然繊維
# 106681BK   2017-07-28    824.00            中国　部門１　　  手袋帽子マフラＳ     天然繊維
# 422843YL   2017-07-28   1951.00            フィリピン　１　   バッグ・サイフ     天然繊維
# 308996B    2017-07-28   1117.00            インド　１　　　   バッグ・サイフ      布製品
# 422707     2017-07-28    737.70            フィリピン　１　  実用小物・消耗品      木製品
# 190225     2017-07-28    959.00            韓国　　　　　　    アクセサリー     金属製品
# 301974     2017-07-28     80.01            インド　１　　　      台所用品    ガラス製品
# 301975     2017-07-28     63.82            インド　１　　　      台所用品    ガラス製品
# 308229GY   2017-07-28    433.00            インド　１　　　   Ｋ／Ｔ　Ｄ／Ｃ      布製品
# 308229WH   2017-07-28    433.00            インド　１　　　   Ｋ／Ｔ　Ｄ／Ｃ      布製品
# 307858BE   2017-07-28    668.00            インド　１　　　   バッグ・サイフ      布製品
# 308407     2017-07-28    182.48            インド　１　　　  実用小物・消耗品     金属製品
# 308451BR   2017-07-28    197.00            インド　１　　　      ハンカチ      布製品
# 308451NV   2017-07-28    197.00            インド　１　　　      ハンカチ      布製品
# 371595     2017-07-28   1243.32            ベトナム　　　　      台所用品    ガラス製品
# 999000     2017-07-28      0.00                 NaN       その他      その他
# 307858BE   2017-07-28    668.00            インド　１　　　   バッグ・サイフ      布製品
# 303057GY   2017-07-28    361.00            インド　１　　　   Ｌ／Ｍ　Ｔ／Ｍ      布製品
# 303115     2017-07-28    256.85            インド　１　　　      台所用品    ガラス製品
# 106684BK   2017-07-28   1360.00            中国　部門１　　   バッグ・サイフ      その他
# 105976WH   2017-07-28   1178.00            中国　部門１　　  手袋帽子マフラＳ     天然繊維
# 371338     2017-07-28    123.04            ベトナム　　　　      台所用品    ガラス製品
#
#                                  size  \
# product_id
# 103591                     ８８×６０×７２ｃｍ
# 102862                １８．５×２４．５×８．５ｃｍ
# 104782                     ４２×２０×３６ｃｍ
# 999000                            NaN
# 190038                          ４５ｃｍ
# 190039                        １８．５ｃｍ
# 190044                          １８ｃｍ
# 190046                          ５０ｃｍ
# 190047                     １．５×４．５ｃｍ
# 190064                           １１号
# 190065                            ９号
# 190066                           １１号
# 190067                            ９号
# 190094OR     フラワー：φ１．５ｃｍ　　スワロ：φ０．５ｃｍ
# 190094WH     フラワー：φ１．５ｃｍ　　スワロ：φ０．５ｃｍ
# 190117                       ２．５×２ｃｍ
# 190119                       １．８×１ｃｍ
# 308353BL            Ｗ１２０ＸＬ１８０ｃｍ（ＡＢＴ）
# 308353GN            Ｗ１２０×Ｌ１８０ｃｍ（ＡＢＴ）
# 308353MT            Ｗ１２０×Ｌ１８０ｃｍ（ＡＢＴ）
# 308353NV            Ｗ１２０×Ｌ１８０ｃｍ（ＡＢＴ）
# 308353PK            Ｗ１２０×Ｌ１８０ｃｍ（ＡＢＴ）
# 371337                       φ９．５×９ｃｍ
# 371338                     φ８．５×７．５ｃｍ
# 371424                φ９×１０ｃｍ＜３３０ｍｌ＞
# 371426                φ９×１０ｃｍ＜３００ｍｌ＞
# 190056             チェーン４１ｃｍ　　φ０．３ｃｍ
# 103434OR                 Ｗ２０×Ｄ３×Ｈ１２ｃｍ
# 307899BL                  ３８×１５×３０ｃｍ
# 307899OR                  ３８×１５×３０ｃｍ
# ...                               ...
# 307001                  Ｗ６×Ｄ４×Ｈ１２．５ｃｍ
# 307002                   Ｗ６×Ｄ４×Ｈ８．５ｃｍ
# 308973                Ｗ４×Ｄ２．３×Ｈ１．５ｃｍ
# 371738            ＢＯＴＴＬＥ：Φ９（Ｂ）×Ｈ１９ｃｍ
# 371814             φ１４（ＢＯＴＴＯＭ）×Ｈ２６ｃｍ
# 371902              φ１２．５（ＴＯＰ）×Ｈ１８ｃｍ
# 106681BK             頭囲５８ｃｍ（ブリムＬ８．５）
# 106624NV        φ２３（Ｔ）×Ｈ２０ｃｍ（持ち手Ｈ１０）
# 106673NV        φ２５（Ｔ）×Ｈ２６ｃｍ（持ち手Ｈ１４）
# 106681BK             頭囲５８ｃｍ（ブリムＬ８．５）
# 422843YL     Ｗ２７（ＴＯＰ）×Ｄ１５（ＴＯＰ）×Ｈ２０ｃｍ
# 308996B        Ｗ２２×Ｄ１６×Ｈ２０ｃｍ（持ち手Ｈ１０）
# 422707      Ｗ１８×Ｄ１８×Ｈ１２ｃｍ（ワイヤーＬ４５ｃｍ）
# 190225                   Ｗ１．２×Ｈ１．２ｃｍ
# 301974                    Φ６．２×Ｈ７．５ｃｍ
# 301975                        Φ６×Ｈ６ｃｍ
# 308229GY                     ４０×６０ｃｍ
# 308229WH                     ４０×６０ｃｍ
# 307858BE                  ２０×１０×１７ｃｍ
# 308407                  Ｗ９×Ｄ１．５×Ｈ１ｃｍ
# 308451BR                   Ｗ５０×Ｌ５０ｃｍ
# 308451NV                   Ｗ５０×Ｌ５０ｃｍ
# 371595             φ２０（ＢＯＴＴＯＭ）×Ｈ２４ｃｍ
# 999000                            NaN
# 307858BE                  ２０×１０×１７ｃｍ
# 303057GY                   Ｗ４２×Ｌ３２ｃｍ
# 303115                     φ７．５×Ｈ８ｃｍ
# 106684BK                   Ｗ３５×Ｈ３６ｃｍ
# 105976WH                 頭囲５２ｃｍ（ブリム４）
# 371338                     φ８．５×７．５ｃｍ
#
#                                                       quality  \
# product_id
# 103591                                                    NaN
# 102862                                                （ＣＥＤＡＲ）
# 104782                                                   ＩＲＯＮ
# 999000                                                    NaN
# 190038      ＳＩＬＶＥＲ９２５（１６－Ｋ　ＧＯＬＤ　ＰＬＡＴＥＤ）　ＰＵ：ＡＭＥＴＨＹＳＴ　Ｌ・ＧＹ：Ｌ...
# 190039      ＳＩＬＶＥＲ９２５（１６－Ｋ　ＧＯＬＤ　ＰＬＡＴＥＤ）　ＰＵ：ＡＭＥＴＨＹＳＴ　Ｌ・ＧＹ：Ｌ...
# 190044         ＳＩＬＶＥＲ９２５（１６－Ｋ　ＧＯＬＤ　ＰＬＡＴＥＤ）　ＷＡＴＥＲ　ＰＥＡＲＬ　　＊ポーチ付
# 190046                 ＳＩＬＶＥＲ９２５（１６－Ｋ　ＧＯＬＤ　ＰＬＡＴＥＤ）　ＢＲＡＳＳ＝ＰＩＰＥ
# 190047                 ＳＩＬＶＥＲ９２５（１６－Ｋ　ＧＯＬＤ　ＰＬＡＴＥＤ）　ＢＲＡＳＳ＝ＰＩＰＥ
# 190064      ＳＩＬＶＥＲ９２５　１６－Ｋ　ＧＯＬＤ　ＰＬＡＴＥＤ　　ＣＵＢＩＣ　ＺＩＲＣＯＮＩＡ　　＊ポ...
# 190065      ＳＩＬＶＥＲ９２５　１６－Ｋ　ＧＯＬＤ　ＰＬＡＴＥＤ　　ＣＵＢＩＣ　ＺＩＲＣＯＮＩＡ　　＊ポ...
# 190066              ＳＩＬＶＥＲ９２５（１６－Ｋ）　　ＩＭＩＴＡＴＩＯＮ　ＰＥＡＲＬ　　＊ポーチ付
# 190067              ＳＩＬＶＥＲ９２５（１６－Ｋ）　　ＩＭＩＴＡＴＩＯＮ　ＰＥＡＲＬ　　＊ポーチ付
# 190094OR    ＺＩＮＣ　　ＥＰＯＸＹ　　ＩＭＩＴＡＴＩＯＮ　ＰＥＡＲＬＳＷＡＲＯＶＳＫＩ　　ＰＯＳＴ：ＳＩ...
# 190094WH    ＺＩＮＣ　　ＥＰＯＸＹ　　ＩＭＩＴＡＴＩＯＮ　ＰＥＡＲＬＳＷＡＲＯＶＳＫＩ　　ＰＯＳＴ：ＳＩ...
# 190117                           ＩＭＩＴＡＴＩＯＮ　ＰＥＡＲＬ　　ＢＲＡＳＳ　　ＺＩＮＫ
# 190119                         ＩＭＩＴＡＴＩＯＮ　ＰＥＡＲＬ　　ＢＲＡＳＳ　　ＺＩＮＣ
# 308353BL                                         ＬＩＮＥＮ　１００％
# 308353GN                                         ＬＩＮＥＮ　１００％
# 308353MT                                         ＬＩＮＥＮ　１００％
# 308353NV                                         ＬＩＮＥＮ　１００％
# 308353PK                                         ＬＩＮＥＮ　１００％
# 371337                              ＲＥＣＹＣＬＥ　ＧＬＡＳＳ　　容量：２５０ｍｌ
# 371338                              ＲＥＣＹＣＬＥ　ＧＬＡＳＳ　　容量：１５０ｍｌ
# 371424                                          ＲＥＣＹＣＬＥ　ＧＬＡＳＳ
# 371426                                          ＲＥＣＹＣＬＥ　ＧＬＡＳＳ
# 190056      ＳＩＬＶＥＲ９２５　１６－Ｋ　ＧＯＬＤ　ＰＬＡＴＥＤ　　ＣＵＢＩＣ　ＺＩＲＣＯＮＩＡ　　＊ポ...
# 103434OR                                                ＰＡＰＥＲ
# 307899BL                        ＬＡＭＩＮＡＴＥ　ＣＡＮＶＡＳ　ＣＯＴＴＯＮ　１００％
# 307899OR                        ＬＡＭＩＮＡＴＥ　ＣＡＮＶＡＳ　ＣＯＴＴＯＮ　１００％
# ...                                                       ...
# 307001                                                ＢＲＡＳＳ
# 307002                                                ＢＲＡＳＳ
# 308973                                                ＢＲＡＳＳ
# 371738        ＴＲＡＹ：Φ７．５（Ｔ）×Ｈ５ｃｍ（ＨＯＬＥ：Φ３．５ｃｍ）　　ＲＥＣＹＣＬＥ　ＧＬＡＳＳ
# 371814                                        ＲＥＣＹＣＬＥ　ＧＬＡＳＳ
# 371902                             容量：１０００ｍｌ　　ＲＥＣＹＣＬＥ　ＧＬＡＳＳ
# 106681BK    サイズ調整－２ｃｍ　　ＰＡＰＥＲ　　ＬＩＮＥＮ　５０％　　ＣＯＴＴＯＮ　５０％　　ＬＩＮＩＮ...
# 106624NV    ＰＯＬＹＰＲＯＰＹＬＥＮＥ　　ＬＩＮＩＮＧ：ＰＯＬＹＥＳＴＥＲ　８０％　　ＣＯＴＴＯＮ　２０...
# 106673NV                          ＰＡＰＥＲ　　ＬＩＮＩＮＧ：ＣＯＴＴＯＮ　１００％
# 106681BK    サイズ調整－２ｃｍ　　ＰＡＰＥＲ　　ＬＩＮＥＮ　５０％　　ＣＯＴＴＯＮ　５０％　　ＬＩＮＩＮ...
# 422843YL                                   （持ち手Ｈ：１９ｃｍ）ＡＢＡＣＡ
# 308996B     ＣＡＮＶＡＳ　ＣＯＴＴＯＮ　１００％　　ＬＩＮＩＮＧ：ＣＡＮＶＡＳ　ＣＯＴＴＯＮ　１００％※...
# 422707                                   ＲＥＣＹＣＬＥ　ＷＯＯＤ　　ＩＲＯＮ
# 190225      ＷＡＴＥＲ　ＰＥＡＲＬ　　ＢＲＡＳＳ（１６ＫＧＰ）　　ＣＵＢＩＣ　ＺＩＲＣＯＮＩＡ　　ＣＡＴ...
# 301974                                     １２０ｍｌ＊Ｒｅｇｕｌａｒ　ｉｔｅｍ
# 301975                                      ８０ｍｌ＊Ｒｅｇｕｌａｒ　ｉｔｅｍ
# 308229GY                                         ＬＩＮＥＮ　１００％
# 308229WH                                         ＬＩＮＥＮ　１００％
# 307858BE                       ＬＩＮＥＮ　１００％　　ＬＩＮＩＮＧ：ＬＩＮＥＮ　１００％
# 308407                                                ＢＲＡＳＳ
# 308451BR                                        ＣＯＴＴＯＮ　１００％
# 308451NV                                        ＣＯＴＴＯＮ　１００％
# 371595                               容量：５５００ｍｌ　　ＲＥＣＹＣＬＥ　ＧＬＡＳＳ
# 999000                                                    NaN
# 307858BE                       ＬＩＮＥＮ　１００％　　ＬＩＮＩＮＧ：ＬＩＮＥＮ　１００％
# 303057GY                            ＦＲＯＮＴ＆ＬＩＮＩＮＧ：ＬＩＮＥＮ　１００％
# 303115                                      容量：２８０ｍｌ　　ＧＬＡＳＳ
# 106684BK    ＰＯＬＹＰＲＯＰＹＬＥＮＥ　　ＬＩＮＩＮＧ：ＬＩＮＥＮ　５５％　　ＣＯＴＴＯＮ　４５％　　Ｈ...
# 105976WH                ３～４歳　　ＲＡＦＦＩＡ　　ＲＩＢＢＯＮ：ＰＯＬＹＥＳＴＥＲ　１００％
# 371338                              ＲＥＣＹＣＬＥ　ＧＬＡＳＳ　　容量：１５０ｍｌ
#
#                         brand                    sub_category     size_letter
# product_id
# 103591                    NaN         アンティークシダー,テーブル,フォールディング               ｌ
# 102862                    NaN               アンティークシダー,カードホルダー  no size letter
# 104782                    NaN                 カード,ティーフフィル,ラック  no size letter
# 999000                    NaN                           立替,送料  no size letter
# 190038                    NaN          インターバル,ストーン,ネックレス,ヴァリエ  no size letter
# 190039                    NaN         インターバル,ストーン,ブレスレット,ヴァリエ  no size letter
# 190044                    NaN            アレンジ,ウォーターパール,ブレスレット  no size letter
# 190046                    NaN                ティップ,ネックレス,ｂｒａｓｓ  no size letter
# 190047                    NaN                  ティップ,ピアス,ｂｒａｓｓ  no size letter
# 190064                  ＜ＶＬＶ＞                セット,リング,１１号,ｌｉｎｅ  no size letter
# 190065                  ＜ＶＬＶ＞                 セット,リング,９号,ｌｉｎｅ  no size letter
# 190066                  ＜ＶＬＶ＞               セット,リング,１１号,ｐｅａｒｌ  no size letter
# 190067                  ＜ＶＬＶ＞                セット,リング,９号,ｐｅａｒｌ  no size letter
# 190094OR                ＜ＶＬＶ＞          ジェルフラワー＆スワロフスキー,ピアスセット  no size letter
# 190094WH                ＜ＶＬＶ＞          ジェルフラワー＆スワロフスキー,ピアスセット  no size letter
# 190117                  ＜ＶＬＶ＞                   パール,ヘアーゴム,ライズ  no size letter
# 190119                  ＜ＶＬＶ＞             パール,フォールドスクエア,ヘアーゴム  no size letter
# 308353BL                ＜ＶＬＶ＞            ストール,ソリッドカラー,ツイル,リネン  no size letter
# 308353GN                ＜ＶＬＶ＞            ストール,ソリッドカラー,ツイル,リネン  no size letter
# 308353MT                ＜ＶＬＶ＞            ストール,ソリッドカラー,ツイル,リネン  no size letter
# 308353NV                ＜ＶＬＶ＞            ストール,ソリッドカラー,ツイル,リネン  no size letter
# 308353PK                ＜ＶＬＶ＞            ストール,ソリッドカラー,ツイル,リネン  no size letter
# 371337      ＜ＨＰ＞＊Ｒｅｇｕｌａｒ　ｉｔｅｍ                     リューズガラス,ｔｅａ               ｌ
# 371338      ＜ＨＰ＞＊Ｒｅｇｕｌａｒ　ｉｔｅｍ                     リューズガラス,ｔｅａ               ｓ
# 371424                    NaN             ストレート,マグカップ,リューズガラス               ｌ
# 371426                    NaN              マグカップ,ラウンド,リューズガラス               ｌ
# 190056                  ＜ＶＬＶ＞               キュービック,ネックレス,ラウンド  no size letter
# 103434OR                  NaN                    アンダリチェック,ポーチ               ｌ
# 307899BL                 ＜ＨＰ＞      クロース,フラワー,マーケットバッグ,ｗ／ラミネート  no size letter
# 307899OR                 ＜ＨＰ＞      クロース,フラワー,マーケットバッグ,ｗ／ラミネート  no size letter
# ...                       ...                             ...             ...
# 307001      ＜ＨＰ＞＊Ｒｅｇｕｌａｒ　ｉｔｅｍ                 アクセサリー,スタンド,ブラス               ｌ
# 307002      ＜ＨＰ＞＊Ｒｅｇｕｌａｒ　ｉｔｅｍ                 アクセサリー,スタンド,ブラス               ｓ
# 308973                   ＜ＨＰ＞          カードスタンド,ワイド,ｂｒａｓｓ,ｓ／１０  no size letter
# 371738                   ＜ＨＰ＞                 バルブ,ボトル,リューズガラス               ｌ
# 371814                   ＜ＨＰ＞             ネック,フラワーベース,リューズガラス               ｓ
# 371902                   ＜ＨＰ＞       クーレライン,テーパー,ピッチャー,リューズガラス               ｌ
# 106681BK                 ＜ｅａ＞                   アンダリ,ティアー,ハット  no size letter
# 106624NV                 ＜ｅａ＞                  コロール,テーパード,バッグ  no size letter
# 106673NV                 ＜ｅａ＞              アンダリ,ウェーブ,バッグ,リップル  no size letter
# 106681BK                 ＜ｅａ＞                   アンダリ,ティアー,ハット  no size letter
# 422843YL                ＜ＶＬＶ＞                   バッグ,パウロ,ａｂａｃａ  no size letter
# 308996B                  ＜ＨＰ＞      キャンバス,タイル,トートバッグ,フィールストライプ  no size letter
# 422707                   ＜ＨＰ＞           ハンギングｂｏｘ,ｒｅｃｙｃｌｅ,ｗｏｏｄ               ｓ
# 190225                  ＜ＶＬＶ＞                 ピアス,フラワー,リファインド  no size letter
# 301974                    NaN                    カップ,グラス,バーレル               ｌ
# 301975                    NaN                    カップ,グラス,バーレル               ｓ
# 308229GY                 ＜ＨＰ＞            シェヴロン,ディッシュクロス,ｌｉｎｅｎ  no size letter
# 308229WH                 ＜ＨＰ＞            シェヴロン,ディッシュクロス,ｌｉｎｅｎ  no size letter
# 307858BE                 ＜ＨＰ＞  ソリッドカラー,フラワー,ランチバッグ,リネン,ｗ／ポイント  no size letter
# 308407      ＜ＨＰ＞＊Ｒｅｇｕｌａｒ　ｉｔｅｍ                  カトラリーレスト,ｂｒａｓｓ  no size letter
# 308451BR                 ＜ＨＰ＞        ストライプ,ディープカラー,ハンカチ,ｔｗｉｌｌ  no size letter
# 308451NV                 ＜ＨＰ＞        ストライプ,ディープカラー,ハンカチ,ｔｗｉｌｌ  no size letter
# 371595                    NaN       キャニスター,コンテント,プランプ,リューズガラス               ｌ
# 999000                    NaN                           立替,送料  no size letter
# 307858BE                 ＜ＨＰ＞  ソリッドカラー,フラワー,ランチバッグ,リネン,ｗ／ポイント  no size letter
# 303057GY                 ＜ＨＰ＞                カロリーナ,ランチマット,リネン  no size letter
# 303115                   ＜ＨＰ＞                    ヒートレジスタント,マグ               ｍ
# 106684BK                 ＜ｅａ＞            クルサール,ハンドル,バッグ,パイピング  no size letter
# 105976WH                 ＜ｅａ＞          スタンピング,ｋｉｄ’ｓハット,ｒａｆｆｉａ  no size letter
# 371338      ＜ＨＰ＞＊Ｒｅｇｕｌａｒ　ｉｔｅｍ                     リューズガラス,ｔｅａ               ｓ
#
# [876339 rows x 16 columns]

# %% [markdown]
# ### Wrangling with missing or bogus data or any 0 values
# - Either drop NaN data or fillin with reasonable value
# - clean size information
# - Calculate the wholesale price

# %% [markdown]
# ### Export integrated dataframe as a csv in dist directory

# %%
integrated_df.to_csv('dist/cleaned_data.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-09596632d613> in <module>()
# ----> 1 integrated_df.to_csv('dist/cleaned_data.csv')
#
# NameError: name 'integrated_df' is not defined
